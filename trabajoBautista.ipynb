# %%
import os
import pandas as pd
import requests #esta librería se utiliza para descargar archivos de internet

#automatizar la descarga de archivos a partir de links que vienen 
#dentro de un CSV, y los organiza en carpetas según el tipo de información.
def download_file(url, folder):
    try: #Este ciclo hace que, aunque una descarga falle, se siga ejecutando la función
        if pd.notna(url):  # Verificar que no sea NaN
            # Obtener el nombre del archivo del enlace
            filename = url.split('/')[-1] #el archivo se parte a partir de el / y toma el último pedazo
            filepath = os.path.join(folder, filename) #utilizamos os.path.join para denominar
            #el nombre de la carpeta y del archivo
            #ejemplo:
            
            # folder = "DIARIOS"
            # filename = "archivo2025.csv"
            # → DIARIOS/archivo2025.csv


            # Descargar el archivo
            response = requests.get(url) #patición http al servidor
            if response.status_code == 200: #todo salió bien, el archivo está disponible
                with open(filepath, 'wb') as file: #abrir el archivo y trabajar con él, para cerrarlo cuando termine
                    #se utiliza esto porque descargo desde internet texto crudo en forma binaria
                    #w=write b=binary, esto es para guardar exactamente lo que llega del servidor byte por byte
                    #whit evita fugas de recursos, errores raros y archivos dañados
                    file.write(response.content) #esto es para guardar físicamente el archivo descargado
                print(f"Descargado: {filename}")
            else:
                print(f"No se pudo descargar {filename}, Código de estado: {response.status_code}")
    except Exception as e:
        print(f"Error descargando {url}: {e}")

# Rutas de carpetas para cada tipo de archivo
folders = ['DIARIOS', 'EXTREMOS', 'MENSUALES']

# Crear las carpetas si no existen
for folder in folders:
    os.makedirs(folder, exist_ok=True)

# Cargar el archivo
file_path = 'Output_point_layer1.csv'  # Cambiar por la ruta del archivo

df = pd.read_csv(file_path)

# Descargar archivos de cada columna y guardarlos en sus carpetas correspondientes
for index, row in df.iterrows(): #para cada fila del csv.
    download_file(row.get('DIARIOS'), 'DIARIOS')#aquí encuentra el valor de la columna diarios
    download_file(row.get('EXTREMOS'), 'EXTREMOS')
    download_file(row.get('MENSUALES'), 'MENSUALES')

print("\nDescarga completada.")

# Es como si row fuera un diccionario:

# row = {
#   "DIARIOS": "url1",
#   "EXTREMOS": "url2",
#   "MENSUALES": "url3"
# }
#Por eso se usa row y no directamente la columna.
# Porque estás diciendo:

# “Para esta fila, dame el valor que está en la columna DIARIOS.”
# Out:
# Descargado: dia01008.txt
# No se pudo descargar medex01008.txt, Código de estado: 500
# Descargado: mes01008.txt
# Descargado: dia01010.txt
# No se pudo descargar medex01010.txt, Código de estado: 500
# Descargado: mes01010.txt
# Descargado: dia01011.txt
# No se pudo descargar medex01011.txt, Código de estado: 500
# Descargado: mes01011.txt
# Descargado: dia01012.txt
# No se pudo descargar medex01012.txt, Código de estado: 500
# Descargado: mes01012.txt
# Descargado: dia01013.txt
# No se pudo descargar medex01013.txt, Código de estado: 500
# Descargado: mes01013.txt
# Descargado: dia01015.txt
# No se pudo descargar medex01015.txt, Código de estado: 500
# Descargado: mes01015.txt
# Descargado: dia01017.txt
# No se pudo descargar medex01017.txt, Código de estado: 500
# Descargado: mes01017.txt
# Descargado: dia01020.txt
# No se pudo descargar medex01020.txt, Código de estado: 500
# Descargado: mes01020.txt
# Descargado: dia01023.txt
# No se pudo descargar medex01023.txt, Código de estado: 500
# Descargado: mes01023.txt
# Descargado: dia01026.txt
# No se pudo descargar medex01026.txt, Código de estado: 500
# Descargado: mes01026.txt
# Descargado: dia01028.txt
# No se pudo descargar medex01028.txt, Código de estado: 500
# Descargado: mes01028.txt
# Descargado: dia01029.txt
# No se pudo descargar medex01029.txt, Código de estado: 500
# Descargado: mes01029.txt
# Descargado: dia01031.txt
# No se pudo descargar medex01031.txt, Código de estado: 500
# Descargado: mes01031.txt
# Descargado: dia01032.txt
# No se pudo descargar medex01032.txt, Código de estado: 500
# Descargado: mes01032.txt
# Descargado: dia01033.txt
# No se pudo descargar medex01033.txt, Código de estado: 500
# Descargado: mes01033.txt
# Descargado: dia01045.txt
# No se pudo descargar medex01045.txt, Código de estado: 500
# Descargado: mes01045.txt
# Descargado: dia01046.txt
# No se pudo descargar medex01046.txt, Código de estado: 500
# Descargado: mes01046.txt
# Descargado: dia01078.txt
# No se pudo descargar medex01078.txt, Código de estado: 500
# Descargado: mes01078.txt
# Descargado: dia01081.txt
# No se pudo descargar medex01081.txt, Código de estado: 500
# Descargado: mes01081.txt
# Descargado: dia01084.txt
# No se pudo descargar medex01084.txt, Código de estado: 500
# Descargado: mes01084.txt
# Descargado: dia01088.txt
# No se pudo descargar medex01088.txt, Código de estado: 500
# Descargado: mes01088.txt
# Descargado: dia01091.txt
# No se pudo descargar medex01091.txt, Código de estado: 500
# Descargado: mes01091.txt
# Descargado: dia01095.txt
# No se pudo descargar medex01095.txt, Código de estado: 500
# Descargado: mes01095.txt
# Descargado: dia01103.txt
# No se pudo descargar medex01103.txt, Código de estado: 500
# Descargado: mes01103.txt
# Descargado: dia05004.txt
# No se pudo descargar medex05004.txt, Código de estado: 500
# Descargado: mes05004.txt
# Descargado: dia05175.txt
# No se pudo descargar medex05175.txt, Código de estado: 500
# Descargado: mes05175.txt
# Descargado: dia10047.txt
# No se pudo descargar medex10047.txt, Código de estado: 500
# Descargado: mes10047.txt
# Descargado: dia10057.txt
# No se pudo descargar medex10057.txt, Código de estado: 500
# Descargado: mes10057.txt
# Descargado: dia10081.txt
# No se pudo descargar medex10081.txt, Código de estado: 500
# Descargado: mes10081.txt
# Descargado: dia10088.txt
# No se pudo descargar medex10088.txt, Código de estado: 500
# Descargado: mes10088.txt
# Descargado: dia10099.txt
# No se pudo descargar medex10099.txt, Código de estado: 500
# Descargado: mes10099.txt
# Descargado: dia10135.txt
# No se pudo descargar medex10135.txt, Código de estado: 500
# Descargado: mes10135.txt
# Descargado: dia10172.txt
# No se pudo descargar medex10172.txt, Código de estado: 500
# Descargado: mes10172.txt
# Descargado: dia11045.txt
# No se pudo descargar medex11045.txt, Código de estado: 500
# Descargado: mes11045.txt
# Descargado: dia14026.txt
# No se pudo descargar medex14026.txt, Código de estado: 500
# Descargado: mes14026.txt
# Descargado: dia14032.txt
# No se pudo descargar medex14032.txt, Código de estado: 500
# Descargado: mes14032.txt
# Descargado: dia14037.txt
# No se pudo descargar medex14037.txt, Código de estado: 500
# Descargado: mes14037.txt
# Descargado: dia14038.txt
# No se pudo descargar medex14038.txt, Código de estado: 500
# Descargado: mes14038.txt
# Descargado: dia14053.txt
# No se pudo descargar medex14053.txt, Código de estado: 500
# Descargado: mes14053.txt
# Descargado: dia14071.txt
# No se pudo descargar medex14071.txt, Código de estado: 500
# Descargado: mes14071.txt
# Descargado: dia14100.txt
# No se pudo descargar medex14100.txt, Código de estado: 500
# Descargado: mes14100.txt
# Descargado: dia14101.txt
# No se pudo descargar medex14101.txt, Código de estado: 500
# Descargado: mes14101.txt
# Descargado: dia14144.txt
# No se pudo descargar medex14144.txt, Código de estado: 500
# Descargado: mes14144.txt
# Descargado: dia14145.txt
# No se pudo descargar medex14145.txt, Código de estado: 500
# Descargado: mes14145.txt
# Descargado: dia14156.txt
# No se pudo descargar medex14156.txt, Código de estado: 500
# Descargado: mes14156.txt
# Descargado: dia14165.txt
# No se pudo descargar medex14165.txt, Código de estado: 500
# Descargado: mes14165.txt
# Descargado: dia14167.txt
# No se pudo descargar medex14167.txt, Código de estado: 500
# Descargado: mes14167.txt
# Descargado: dia14179.txt
# No se pudo descargar medex14179.txt, Código de estado: 500
# Descargado: mes14179.txt
# Descargado: dia14306.txt
# No se pudo descargar medex14306.txt, Código de estado: 500
# Descargado: mes14306.txt
# Descargado: dia14324.txt
# No se pudo descargar medex14324.txt, Código de estado: 500
# Descargado: mes14324.txt
# Descargado: dia14326.txt
# No se pudo descargar medex14326.txt, Código de estado: 500
# Descargado: mes14326.txt
# Descargado: dia14331.txt
# No se pudo descargar medex14331.txt, Código de estado: 500
# Descargado: mes14331.txt
# Descargado: dia14346.txt
# No se pudo descargar medex14346.txt, Código de estado: 500
# Descargado: mes14346.txt
# Descargado: dia18031.txt
# No se pudo descargar medex18031.txt, Código de estado: 500
# Descargado: mes18031.txt
# Descargado: dia24055.txt
# No se pudo descargar medex24055.txt, Código de estado: 500
# Descargado: mes24055.txt
# Descargado: dia24059.txt
# No se pudo descargar medex24059.txt, Código de estado: 500
# Descargado: mes24059.txt
# Descargado: dia24074.txt
# No se pudo descargar medex24074.txt, Código de estado: 500
# Descargado: mes24074.txt
# Descargado: dia24077.txt
# No se pudo descargar medex24077.txt, Código de estado: 500
# Descargado: mes24077.txt
# Descargado: dia24100.txt
# No se pudo descargar medex24100.txt, Código de estado: 500
# Descargado: mes24100.txt
# Descargado: dia24144.txt
# No se pudo descargar medex24144.txt, Código de estado: 500
# Descargado: mes24144.txt
# Descargado: dia24146.txt
# No se pudo descargar medex24146.txt, Código de estado: 500
# Descargado: mes24146.txt
# Descargado: dia24148.txt
# No se pudo descargar medex24148.txt, Código de estado: 500
# Descargado: mes24148.txt
# Descargado: dia24150.txt
# No se pudo descargar medex24150.txt, Código de estado: 500
# Descargado: mes24150.txt
# Descargado: dia24151.txt
# No se pudo descargar medex24151.txt, Código de estado: 500
# Descargado: mes24151.txt
# Descargado: dia24152.txt
# No se pudo descargar medex24152.txt, Código de estado: 500
# Descargado: mes24152.txt
# Descargado: dia24175.txt
# No se pudo descargar medex24175.txt, Código de estado: 500
# Descargado: mes24175.txt
# Descargado: dia24191.txt
# No se pudo descargar medex24191.txt, Código de estado: 500
# Descargado: mes24191.txt
# Descargado: dia32001.txt
# No se pudo descargar medex32001.txt, Código de estado: 500
# Descargado: mes32001.txt
# Descargado: dia32002.txt
# No se pudo descargar medex32002.txt, Código de estado: 500
# Descargado: mes32002.txt
# Descargado: dia32003.txt
# No se pudo descargar medex32003.txt, Código de estado: 500
# Descargado: mes32003.txt
# Descargado: dia32004.txt
# No se pudo descargar medex32004.txt, Código de estado: 500
# Descargado: mes32004.txt
# Descargado: dia32005.txt
# No se pudo descargar medex32005.txt, Código de estado: 500
# Descargado: mes32005.txt
# Descargado: dia32006.txt
# No se pudo descargar medex32006.txt, Código de estado: 500
# Descargado: mes32006.txt
# Descargado: dia32007.txt
# No se pudo descargar medex32007.txt, Código de estado: 500
# Descargado: mes32007.txt
# Descargado: dia32010.txt
# No se pudo descargar medex32010.txt, Código de estado: 500
# Descargado: mes32010.txt
# Descargado: dia32011.txt
# No se pudo descargar medex32011.txt, Código de estado: 500
# Descargado: mes32011.txt
# Descargado: dia32013.txt
# No se pudo descargar medex32013.txt, Código de estado: 500
# Descargado: mes32013.txt
# Descargado: dia32015.txt
# No se pudo descargar medex32015.txt, Código de estado: 500
# Descargado: mes32015.txt
# Descargado: dia32016.txt
# No se pudo descargar medex32016.txt, Código de estado: 500
# Descargado: mes32016.txt
# Descargado: dia32018.txt
# No se pudo descargar medex32018.txt, Código de estado: 500
# Descargado: mes32018.txt
# Descargado: dia32019.txt
# No se pudo descargar medex32019.txt, Código de estado: 500
# Descargado: mes32019.txt
# Descargado: dia32020.txt
# No se pudo descargar medex32020.txt, Código de estado: 500
# Descargado: mes32020.txt
# Descargado: dia32021.txt
# No se pudo descargar medex32021.txt, Código de estado: 500
# Descargado: mes32021.txt
# Descargado: dia32022.txt
# No se pudo descargar medex32022.txt, Código de estado: 500
# Descargado: mes32022.txt
# Descargado: dia32024.txt
# No se pudo descargar medex32024.txt, Código de estado: 500
# Descargado: mes32024.txt
# Descargado: dia32025.txt
# No se pudo descargar medex32025.txt, Código de estado: 500
# Descargado: mes32025.txt
# Descargado: dia32026.txt
# No se pudo descargar medex32026.txt, Código de estado: 500
# Descargado: mes32026.txt
# Descargado: dia32027.txt
# No se pudo descargar medex32027.txt, Código de estado: 500
# Descargado: mes32027.txt
# Descargado: dia32028.txt
# No se pudo descargar medex32028.txt, Código de estado: 500
# Descargado: mes32028.txt
# Descargado: dia32029.txt
# No se pudo descargar medex32029.txt, Código de estado: 500
# Descargado: mes32029.txt
# Descargado: dia32030.txt
# No se pudo descargar medex32030.txt, Código de estado: 500
# Descargado: mes32030.txt
# Descargado: dia32031.txt
# No se pudo descargar medex32031.txt, Código de estado: 500
# Descargado: mes32031.txt
# Descargado: dia32032.txt
# No se pudo descargar medex32032.txt, Código de estado: 500
# Descargado: mes32032.txt
# Descargado: dia32033.txt
# No se pudo descargar medex32033.txt, Código de estado: 500
# Descargado: mes32033.txt
# Descargado: dia32034.txt
# No se pudo descargar medex32034.txt, Código de estado: 500
# Descargado: mes32034.txt
# Descargado: dia32036.txt
# No se pudo descargar medex32036.txt, Código de estado: 500
# Descargado: mes32036.txt
# Descargado: dia32037.txt
# No se pudo descargar medex32037.txt, Código de estado: 500
# Descargado: mes32037.txt
# Descargado: dia32038.txt
# No se pudo descargar medex32038.txt, Código de estado: 500
# Descargado: mes32038.txt
# Descargado: dia32039.txt
# No se pudo descargar medex32039.txt, Código de estado: 500
# Descargado: mes32039.txt
# Descargado: dia32040.txt
# No se pudo descargar medex32040.txt, Código de estado: 500
# Descargado: mes32040.txt
# Descargado: dia32041.txt
# No se pudo descargar medex32041.txt, Código de estado: 500
# Descargado: mes32041.txt
# Descargado: dia32042.txt
# No se pudo descargar medex32042.txt, Código de estado: 500
# Descargado: mes32042.txt
# Descargado: dia32045.txt
# No se pudo descargar medex32045.txt, Código de estado: 500
# Descargado: mes32045.txt
# Descargado: dia32046.txt
# No se pudo descargar medex32046.txt, Código de estado: 500
# Descargado: mes32046.txt
# Descargado: dia32047.txt
# No se pudo descargar medex32047.txt, Código de estado: 500
# Descargado: mes32047.txt
# Descargado: dia32048.txt
# No se pudo descargar medex32048.txt, Código de estado: 500
# Descargado: mes32048.txt
# Descargado: dia32049.txt
# No se pudo descargar medex32049.txt, Código de estado: 500
# Descargado: mes32049.txt
# Descargado: dia32050.txt
# No se pudo descargar medex32050.txt, Código de estado: 500
# Descargado: mes32050.txt
# Descargado: dia32051.txt
# No se pudo descargar medex32051.txt, Código de estado: 500
# Descargado: mes32051.txt
# Descargado: dia32052.txt
# No se pudo descargar medex32052.txt, Código de estado: 500
# Descargado: mes32052.txt
# Descargado: dia32053.txt
# No se pudo descargar medex32053.txt, Código de estado: 500
# Descargado: mes32053.txt
# Descargado: dia32054.txt
# No se pudo descargar medex32054.txt, Código de estado: 500
# Descargado: mes32054.txt
# Descargado: dia32055.txt
# No se pudo descargar medex32055.txt, Código de estado: 500
# Descargado: mes32055.txt
# Descargado: dia32057.txt
# No se pudo descargar medex32057.txt, Código de estado: 500
# Descargado: mes32057.txt
# Descargado: dia32058.txt
# No se pudo descargar medex32058.txt, Código de estado: 500
# Descargado: mes32058.txt
# Descargado: dia32059.txt
# No se pudo descargar medex32059.txt, Código de estado: 500
# Descargado: mes32059.txt
# Descargado: dia32061.txt
# No se pudo descargar medex32061.txt, Código de estado: 500
# Descargado: mes32061.txt
# Descargado: dia32065.txt
# No se pudo descargar medex32065.txt, Código de estado: 500
# Descargado: mes32065.txt
# Descargado: dia32068.txt
# No se pudo descargar medex32068.txt, Código de estado: 500
# Descargado: mes32068.txt
# Descargado: dia32069.txt
# No se pudo descargar medex32069.txt, Código de estado: 500
# Descargado: mes32069.txt
# Descargado: dia32070.txt
# No se pudo descargar medex32070.txt, Código de estado: 500
# Descargado: mes32070.txt
# Descargado: dia32072.txt
# No se pudo descargar medex32072.txt, Código de estado: 500
# Descargado: mes32072.txt
# Descargado: dia32073.txt
# No se pudo descargar medex32073.txt, Código de estado: 500
# Descargado: mes32073.txt
# Descargado: dia32076.txt
# No se pudo descargar medex32076.txt, Código de estado: 500
# Descargado: mes32076.txt
# Descargado: dia32078.txt
# No se pudo descargar medex32078.txt, Código de estado: 500
# Descargado: mes32078.txt
# Descargado: dia32084.txt
# No se pudo descargar medex32084.txt, Código de estado: 500
# Descargado: mes32084.txt
# Descargado: dia32085.txt
# No se pudo descargar medex32085.txt, Código de estado: 500
# Descargado: mes32085.txt
# Descargado: dia32086.txt
# No se pudo descargar medex32086.txt, Código de estado: 500
# Descargado: mes32086.txt
# Descargado: dia32087.txt
# No se pudo descargar medex32087.txt, Código de estado: 500
# Descargado: mes32087.txt
# Descargado: dia32091.txt
# No se pudo descargar medex32091.txt, Código de estado: 500
# Descargado: mes32091.txt
# Descargado: dia32093.txt
# No se pudo descargar medex32093.txt, Código de estado: 500
# Descargado: mes32093.txt
# Descargado: dia32095.txt
# No se pudo descargar medex32095.txt, Código de estado: 500
# Descargado: mes32095.txt
# Descargado: dia32097.txt
# No se pudo descargar medex32097.txt, Código de estado: 500
# Descargado: mes32097.txt
# Descargado: dia32098.txt
# No se pudo descargar medex32098.txt, Código de estado: 500
# Descargado: mes32098.txt
# Descargado: dia32099.txt
# No se pudo descargar medex32099.txt, Código de estado: 500
# Descargado: mes32099.txt
# Descargado: dia32100.txt
# No se pudo descargar medex32100.txt, Código de estado: 500
# Descargado: mes32100.txt
# Descargado: dia32101.txt
# No se pudo descargar medex32101.txt, Código de estado: 500
# Descargado: mes32101.txt
# Descargado: dia32103.txt
# No se pudo descargar medex32103.txt, Código de estado: 500
# Descargado: mes32103.txt
# Descargado: dia32105.txt
# No se pudo descargar medex32105.txt, Código de estado: 500
# Descargado: mes32105.txt
# Descargado: dia32106.txt
# No se pudo descargar medex32106.txt, Código de estado: 500
# Descargado: mes32106.txt
# Descargado: dia32107.txt
# No se pudo descargar medex32107.txt, Código de estado: 500
# Descargado: mes32107.txt
# Descargado: dia32108.txt
# No se pudo descargar medex32108.txt, Código de estado: 500
# Descargado: mes32108.txt
# Descargado: dia32109.txt
# No se pudo descargar medex32109.txt, Código de estado: 500
# Descargado: mes32109.txt
# Descargado: dia32111.txt
# No se pudo descargar medex32111.txt, Código de estado: 500
# Descargado: mes32111.txt
# Descargado: dia32112.txt
# No se pudo descargar medex32112.txt, Código de estado: 500
# Descargado: mes32112.txt
# Descargado: dia32113.txt
# No se pudo descargar medex32113.txt, Código de estado: 500
# Descargado: mes32113.txt
# Descargado: dia32114.txt
# No se pudo descargar medex32114.txt, Código de estado: 500
# Descargado: mes32114.txt
# Descargado: dia32115.txt
# No se pudo descargar medex32115.txt, Código de estado: 500
# Descargado: mes32115.txt
# Descargado: dia32116.txt
# No se pudo descargar medex32116.txt, Código de estado: 500
# Descargado: mes32116.txt
# Descargado: dia32117.txt
# No se pudo descargar medex32117.txt, Código de estado: 500
# Descargado: mes32117.txt
# Descargado: dia32118.txt
# No se pudo descargar medex32118.txt, Código de estado: 500
# Descargado: mes32118.txt
# Descargado: dia32119.txt
# No se pudo descargar medex32119.txt, Código de estado: 500
# Descargado: mes32119.txt
# Descargado: dia32120.txt
# No se pudo descargar medex32120.txt, Código de estado: 500
# Descargado: mes32120.txt
# Descargado: dia32121.txt
# No se pudo descargar medex32121.txt, Código de estado: 500
# Descargado: mes32121.txt
# Descargado: dia32122.txt
# No se pudo descargar medex32122.txt, Código de estado: 500
# Descargado: mes32122.txt
# Descargado: dia32123.txt
# No se pudo descargar medex32123.txt, Código de estado: 500
# Descargado: mes32123.txt
# Descargado: dia32124.txt
# No se pudo descargar medex32124.txt, Código de estado: 500
# Descargado: mes32124.txt
# Descargado: dia32125.txt
# No se pudo descargar medex32125.txt, Código de estado: 500
# Descargado: mes32125.txt
# Descargado: dia32126.txt
# No se pudo descargar medex32126.txt, Código de estado: 500
# Descargado: mes32126.txt
# Descargado: dia32127.txt
# No se pudo descargar medex32127.txt, Código de estado: 500
# Descargado: mes32127.txt
# Descargado: dia32129.txt
# No se pudo descargar medex32129.txt, Código de estado: 500
# Descargado: mes32129.txt
# Descargado: dia32130.txt
# No se pudo descargar medex32130.txt, Código de estado: 500
# Descargado: mes32130.txt
# Descargado: dia32131.txt
# No se pudo descargar medex32131.txt, Código de estado: 500
# Descargado: mes32131.txt
# Descargado: dia32132.txt
# No se pudo descargar medex32132.txt, Código de estado: 500
# Descargado: mes32132.txt
# Descargado: dia32133.txt
# No se pudo descargar medex32133.txt, Código de estado: 500
# Descargado: mes32133.txt
# Descargado: dia32134.txt
# No se pudo descargar medex32134.txt, Código de estado: 500
# Descargado: mes32134.txt
# Descargado: dia32135.txt
# No se pudo descargar medex32135.txt, Código de estado: 500
# Descargado: mes32135.txt
# Descargado: dia32137.txt
# No se pudo descargar medex32137.txt, Código de estado: 500
# Descargado: mes32137.txt
# Descargado: dia32139.txt
# No se pudo descargar medex32139.txt, Código de estado: 500
# Descargado: mes32139.txt
# Descargado: dia32140.txt
# No se pudo descargar medex32140.txt, Código de estado: 500
# Descargado: mes32140.txt
# Descargado: dia32142.txt
# No se pudo descargar medex32142.txt, Código de estado: 500
# Descargado: mes32142.txt
# Descargado: dia32143.txt
# No se pudo descargar medex32143.txt, Código de estado: 500
# Descargado: mes32143.txt
# Descargado: dia32148.txt
# No se pudo descargar medex32148.txt, Código de estado: 500
# Descargado: mes32148.txt
# Descargado: dia32150.txt
# No se pudo descargar medex32150.txt, Código de estado: 500
# Descargado: mes32150.txt
# Descargado: dia32151.txt
# No se pudo descargar medex32151.txt, Código de estado: 500
# Descargado: mes32151.txt
# Descargado: dia32171.txt
# No se pudo descargar medex32171.txt, Código de estado: 500
# Descargado: mes32171.txt
# Descargado: dia32172.txt
# No se pudo descargar medex32172.txt, Código de estado: 500
# Descargado: mes32172.txt
# Descargado: dia32173.txt
# No se pudo descargar medex32173.txt, Código de estado: 500
# Descargado: mes32173.txt
# Descargado: dia32174.txt
# No se pudo descargar medex32174.txt, Código de estado: 500
# Descargado: mes32174.txt
# Descargado: dia32176.txt
# No se pudo descargar medex32176.txt, Código de estado: 500
# Descargado: mes32176.txt
# Descargado: dia32177.txt
# No se pudo descargar medex32177.txt, Código de estado: 500
# Descargado: mes32177.txt
# Descargado: dia32179.txt
# No se pudo descargar medex32179.txt, Código de estado: 500
# Descargado: mes32179.txt
# Descargado: dia32180.txt
# No se pudo descargar medex32180.txt, Código de estado: 500
# Descargado: mes32180.txt
# Descargado: dia32184.txt
# No se pudo descargar medex32184.txt, Código de estado: 500
# Descargado: mes32184.txt
# Descargado: dia32186.txt
# No se pudo descargar medex32186.txt, Código de estado: 500
# Descargado: mes32186.txt
# Descargado: dia32187.txt
# No se pudo descargar medex32187.txt, Código de estado: 500
# Descargado: mes32187.txt
# Descargado: dia32188.txt
# No se pudo descargar medex32188.txt, Código de estado: 500
# Descargado: mes32188.txt
# Descargado: dia32189.txt
# No se pudo descargar medex32189.txt, Código de estado: 500
# Descargado: mes32189.txt
# Descargado: dia32191.txt
# No se pudo descargar medex32191.txt, Código de estado: 500
# Descargado: mes32191.txt
# Descargado: dia01003.txt
# No se pudo descargar medex01003.txt, Código de estado: 500
# Descargado: mes01003.txt
# Descargado: dia01006.txt
# No se pudo descargar medex01006.txt, Código de estado: 500
# Descargado: mes01006.txt
# Descargado: dia01009.txt
# No se pudo descargar medex01009.txt, Código de estado: 500
# Descargado: mes01009.txt
# Descargado: dia10015.txt
# No se pudo descargar medex10015.txt, Código de estado: 500
# Descargado: mes10015.txt
# Descargado: dia10032.txt
# No se pudo descargar medex10032.txt, Código de estado: 500
# Descargado: mes10032.txt
# Descargado: dia10034.txt
# No se pudo descargar medex10034.txt, Código de estado: 500
# Descargado: mes10034.txt
# Descargado: dia10059.txt
# No se pudo descargar medex10059.txt, Código de estado: 500
# Descargado: mes10059.txt
# Descargado: dia10067.txt
# No se pudo descargar medex10067.txt, Código de estado: 500
# Descargado: mes10067.txt
# Descargado: dia10070.txt
# No se pudo descargar medex10070.txt, Código de estado: 500
# Descargado: mes10070.txt
# Descargado: dia10074.txt
# No se pudo descargar medex10074.txt, Código de estado: 500
# Descargado: mes10074.txt
# Descargado: dia10151.txt
# No se pudo descargar medex10151.txt, Código de estado: 500
# Descargado: mes10151.txt
# Descargado: dia14025.txt
# No se pudo descargar medex14025.txt, Código de estado: 500
# Descargado: mes14025.txt
# Descargado: dia14069.txt
# No se pudo descargar medex14069.txt, Código de estado: 500
# Descargado: mes14069.txt
# Descargado: dia14098.txt
# No se pudo descargar medex14098.txt, Código de estado: 500
# Descargado: mes14098.txt
# Descargado: dia14103.txt
# No se pudo descargar medex14103.txt, Código de estado: 500
# Descargado: mes14103.txt
# Descargado: dia14108.txt
# No se pudo descargar medex14108.txt, Código de estado: 500
# Descargado: mes14108.txt
# Descargado: dia14134.txt
# No se pudo descargar medex14134.txt, Código de estado: 500
# Descargado: mes14134.txt
# Descargado: dia14135.txt
# No se pudo descargar medex14135.txt, Código de estado: 500
# Descargado: mes14135.txt
# Descargado: dia14153.txt
# No se pudo descargar medex14153.txt, Código de estado: 500
# Descargado: mes14153.txt
# Descargado: dia14161.txt
# No se pudo descargar medex14161.txt, Código de estado: 500
# Descargado: mes14161.txt
# Descargado: dia14175.txt
# No se pudo descargar medex14175.txt, Código de estado: 500
# Descargado: mes14175.txt
# Descargado: dia14176.txt
# No se pudo descargar medex14176.txt, Código de estado: 500
# Descargado: mes14176.txt
# Descargado: dia14186.txt
# No se pudo descargar medex14186.txt, Código de estado: 500
# Descargado: mes14186.txt
# Descargado: dia14192.txt
# No se pudo descargar medex14192.txt, Código de estado: 500
# Descargado: mes14192.txt
# Descargado: dia14196.txt
# No se pudo descargar medex14196.txt, Código de estado: 500
# Descargado: mes14196.txt
# Descargado: dia14319.txt
# No se pudo descargar medex14319.txt, Código de estado: 500
# Descargado: mes14319.txt
# Descargado: dia14345.txt
# No se pudo descargar medex14345.txt, Código de estado: 500
# Descargado: mes14345.txt
# Descargado: dia14347.txt
# No se pudo descargar medex14347.txt, Código de estado: 500
# Descargado: mes14347.txt
# Descargado: dia14363.txt
# No se pudo descargar medex14363.txt, Código de estado: 500
# Descargado: mes14363.txt
# Descargado: dia19129.txt
# No se pudo descargar medex19129.txt, Código de estado: 500
# Descargado: mes19129.txt
# Descargado: dia24127.txt
# No se pudo descargar medex24127.txt, Código de estado: 500
# Descargado: mes24127.txt
# Descargado: dia24147.txt
# No se pudo descargar medex24147.txt, Código de estado: 500
# Descargado: mes24147.txt
# Descargado: dia24166.txt
# No se pudo descargar medex24166.txt, Código de estado: 500
# Descargado: mes24166.txt
# Descargado: dia24194.txt
# No se pudo descargar medex24194.txt, Código de estado: 500
# Descargado: mes24194.txt
# Descargado: dia24196.txt
# No se pudo descargar medex24196.txt, Código de estado: 500
# Descargado: mes24196.txt
# Descargado: dia32009.txt
# No se pudo descargar medex32009.txt, Código de estado: 500
# Descargado: mes32009.txt
# Descargado: dia32012.txt
# No se pudo descargar medex32012.txt, Código de estado: 500
# Descargado: mes32012.txt
# Descargado: dia32014.txt
# No se pudo descargar medex32014.txt, Código de estado: 500
# Descargado: mes32014.txt
# Descargado: dia32017.txt
# No se pudo descargar medex32017.txt, Código de estado: 500
# Descargado: mes32017.txt
# Descargado: dia32023.txt
# No se pudo descargar medex32023.txt, Código de estado: 500
# Descargado: mes32023.txt
# Descargado: dia32043.txt
# No se pudo descargar medex32043.txt, Código de estado: 500
# Descargado: mes32043.txt
# Descargado: dia32056.txt
# No se pudo descargar medex32056.txt, Código de estado: 500
# Descargado: mes32056.txt
# Descargado: dia32060.txt
# No se pudo descargar medex32060.txt, Código de estado: 500
# Descargado: mes32060.txt
# Descargado: dia32062.txt
# No se pudo descargar medex32062.txt, Código de estado: 500
# Descargado: mes32062.txt
# Descargado: dia32063.txt
# No se pudo descargar medex32063.txt, Código de estado: 500
# Descargado: mes32063.txt
# Descargado: dia32067.txt
# No se pudo descargar medex32067.txt, Código de estado: 500
# Descargado: mes32067.txt
# Descargado: dia32071.txt
# No se pudo descargar medex32071.txt, Código de estado: 500
# Descargado: mes32071.txt
# Descargado: dia32074.txt
# No se pudo descargar medex32074.txt, Código de estado: 500
# Descargado: mes32074.txt
# Descargado: dia32077.txt
# No se pudo descargar medex32077.txt, Código de estado: 500
# Descargado: mes32077.txt
# Descargado: dia32080.txt
# No se pudo descargar medex32080.txt, Código de estado: 500
# Descargado: mes32080.txt
# Descargado: dia32088.txt
# No se pudo descargar medex32088.txt, Código de estado: 500
# Descargado: mes32088.txt
# Descargado: dia32089.txt
# No se pudo descargar medex32089.txt, Código de estado: 500
# Descargado: mes32089.txt
# Descargado: dia32090.txt
# No se pudo descargar medex32090.txt, Código de estado: 500
# Descargado: mes32090.txt
# Descargado: dia32092.txt
# No se pudo descargar medex32092.txt, Código de estado: 500
# Descargado: mes32092.txt
# Descargado: dia32096.txt
# No se pudo descargar medex32096.txt, Código de estado: 500
# Descargado: mes32096.txt
# Descargado: dia32102.txt
# No se pudo descargar medex32102.txt, Código de estado: 500
# Descargado: mes32102.txt
# Descargado: dia32104.txt
# No se pudo descargar medex32104.txt, Código de estado: 500
# Descargado: mes32104.txt
# Descargado: dia32110.txt
# No se pudo descargar medex32110.txt, Código de estado: 500
# Descargado: mes32110.txt
# Descargado: dia32136.txt
# No se pudo descargar medex32136.txt, Código de estado: 500
# Descargado: mes32136.txt
# Descargado: dia32138.txt
# No se pudo descargar medex32138.txt, Código de estado: 500
# Descargado: mes32138.txt
# Descargado: dia32141.txt
# No se pudo descargar medex32141.txt, Código de estado: 500
# Descargado: mes32141.txt
# Descargado: dia32144.txt
# No se pudo descargar medex32144.txt, Código de estado: 500
# Descargado: mes32144.txt
#
# Descarga completada.

# %%
import os
import pandas as pd
import requests

# Lista para registrar los errores de extremos
errores_extremos = []

def download_extremo(url, clave):
    try:
        if pd.notna(url):  # Verificar que no sea NaN
            # Crear carpeta EXTREMOS si no existe
            os.makedirs('EXTREMOS', exist_ok=True)

            # Nombre del archivo
            filename = url.split('/')[-1]
            filepath = os.path.join('EXTREMOS', filename)

            # Encabezado para simular navegador
            headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}

            # Realizar solicitud con encabezado
            response = requests.get(url, headers=headers)

            if response.status_code == 200:
                with open(filepath, 'wb') as file:
                    file.write(response.content)
                print(f"Descargado: {filename}")
            else:
                print(f"No se pudo descargar {url}, Código de estado: {response.status_code}")
                errores_extremos.append({'Clave': clave, 'URL': url, 'Código de Error': response.status_code})
    except Exception as e:
        print(f"Error descargando {url}: {e}")
        errores_extremos.append({'Clave': clave, 'URL': url, 'Código de Error': str(e)})

# Ruta del archivo
file_path = 'Output_point_layer1.csv'  # Cambia por el archivo .csv o .xlsx

# Leer el archivo según su extensión
if file_path.endswith('.csv'):
    df = pd.read_csv(file_path)
elif file_path.endswith('.xlsx'):
    df = pd.read_excel(file_path)
else:
    raise ValueError("El archivo debe ser un .csv o .xlsx")

# Descargar solo archivos EXTREMOS
for index, row in df.iterrows():
    clave = row.get('name') or row.get('CLAVE')
    download_extremo(row.get('EXTREMOS'), clave)

# Guardar el reporte de errores en un archivo Excel
if errores_extremos:
    errores_df = pd.DataFrame(errores_extremos)
    errores_df.to_excel('errores_extremos.xlsx', index=False)
    print("\nReporte de errores guardado en 'errores_extremos.xlsx'")
else:
    print("\nTodos los archivos EXTREMOS fueron descargados exitosamente.")

print("\nDescarga de EXTREMOS completada.")
# Out:
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01008.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01008.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01010.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01010.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01011.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01011.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01012.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01012.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01013.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01013.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01015.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01015.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01017.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01017.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01020.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01020.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01023.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01023.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01026.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01026.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01028.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01028.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01029.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01029.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01031.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01031.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01032.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01032.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01033.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01033.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01045.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01045.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01046.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01046.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01078.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01078.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01081.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01081.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01084.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01084.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01088.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01088.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01091.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01091.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01095.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01095.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01103.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/ags/medex01103.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/coah/medex05004.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/coah/medex05004.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/coah/medex05175.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/coah/medex05175.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/dgo/medex10047.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/dgo/medex10047.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/dgo/medex10057.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/dgo/medex10057.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/dgo/medex10081.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/dgo/medex10081.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/dgo/medex10088.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/dgo/medex10088.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/dgo/medex10099.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/dgo/medex10099.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/dgo/medex10135.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/dgo/medex10135.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/dgo/medex10172.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/dgo/medex10172.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/gto/medex11045.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/gto/medex11045.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14026.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14026.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14032.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14032.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14037.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14037.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14038.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14038.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14053.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14053.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14071.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14071.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14100.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14100.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14101.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14101.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14144.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14144.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14145.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14145.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14156.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14156.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14165.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14165.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14167.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14167.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14179.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14179.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14306.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14306.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14324.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14324.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14326.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14326.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14331.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14331.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14346.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14346.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/nay/medex18031.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/nay/medex18031.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24055.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24055.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24059.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24059.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24074.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24074.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24077.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24077.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24100.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24100.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24144.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24144.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24146.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24146.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24148.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24148.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24150.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24150.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24151.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24151.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24152.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24152.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24175.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24175.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24191.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24191.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32001.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32001.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32002.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32002.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32003.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32003.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32004.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32004.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32005.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32005.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32006.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32006.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32007.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32007.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32010.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32010.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32011.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32011.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32013.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32013.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32015.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32015.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32016.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32016.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32018.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32018.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32019.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32019.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32020.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32020.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32021.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32021.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32022.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32022.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32024.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32024.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32025.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32025.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32026.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32026.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32027.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32027.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32028.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32028.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32029.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32029.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32030.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32030.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32031.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32031.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32032.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32032.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32033.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32033.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32034.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32034.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32036.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32036.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32037.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32037.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32038.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32038.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32039.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32039.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32040.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32040.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32041.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32041.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32042.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32042.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32045.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32045.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32046.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32046.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32047.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32047.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32048.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32048.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32049.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32049.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32050.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32050.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32051.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32051.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# ...
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14345.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14345.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14347.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14347.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14363.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/jal/medex14363.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/nl/medex19129.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/nl/medex19129.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24127.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24127.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24147.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24147.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24166.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24166.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24194.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24194.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24196.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/slp/medex24196.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32009.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32009.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32012.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32012.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32014.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32014.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32017.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32017.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32023.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32023.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32043.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32043.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32056.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32056.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32060.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32060.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32062.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32062.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32063.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32063.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32067.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32067.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32071.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32071.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32074.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32074.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32077.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32077.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32080.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32080.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32088.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32088.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32089.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32089.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32090.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32090.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32092.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32092.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32096.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32096.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32102.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32102.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32104.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32104.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32110.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32110.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32136.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32136.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32138.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32138.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32141.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32141.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# Error descargando https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32144.txt: HTTPSConnectionPool(host='smn.conagua.gob.mx', port=443): Max retries exceeded with url: /tools/RESOURCES/Normales_Climatologicas/Med-Extr/zac/medex32144.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
#
# Reporte de errores guardado en 'errores_extremos.xlsx'
#
# Descarga de EXTREMOS completada.

# %%
import os
import pandas as pd
import requests  # librería para descargar archivos de internet

# Automatiza la descarga SOLO de los archivos EXTREMOS
def download_extremo(url):
    try:  # Aunque una descarga falle, el programa sigue
        if pd.notna(url):  # Verifica que no sea NaN
            # Crear la carpeta EXTREMOS si no existe
            os.makedirs('EXTREMOS', exist_ok=True)

            # Obtener el nombre del archivo desde la URL
            filename = url.split('/')[-1]
            filepath = os.path.join('EXTREMOS', filename)
            # Ejemplo:
            # filename = "archivo2025.csv"
            # filepath = "EXTREMOS/archivo2025.csv"
            headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}
            #pusimos verify=false porque nos estaba dando error, ya que es un dominio de gobierno
            response = requests.get(url, headers=headers, verify=False)

            if response.status_code == 200:  # descarga exitosa
                with open(filepath, 'wb') as file:
                    # w = write, b = binary
                    # Guarda exactamente lo que llega del servidor, byte por byte
                    file.write(response.content)
                print(f"Descargado: {filename}")
            else:
                print(f"No se pudo descargar {filename}, Código de estado: {response.status_code}")
    except Exception as e:
        print(f"Error descargando {url}: {e}")


# Cargar el archivo CSV
file_path = 'Output_point_layer1.csv'  # Cambia por tu archivo real
df = pd.read_csv(file_path)

# Descargar únicamente los archivos de la columna EXTREMOS
for index, row in df.iterrows():  # para cada fila del CSV
    download_extremo(row.get('EXTREMOS'))
    # aquí row funciona como:
    # row = {
    #   "DIARIOS": "url1",
    #   "EXTREMOS": "url2",
    #   "MENSUALES": "url3"
    # }
    # Entonces row.get('EXTREMOS') obtiene solo el link de EXTREMOS de esa fila

print("\nDescarga de EXTREMOS completada.")
# Out:
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01008.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01010.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01011.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01012.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01013.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01015.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01017.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01020.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01023.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01026.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01028.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01029.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01031.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01032.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01033.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01045.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01046.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01078.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01081.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01084.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01088.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01091.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01095.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex01103.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex05004.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex05175.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex10047.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex10057.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex10081.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex10088.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex10099.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex10135.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex10172.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex11045.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14026.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14032.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14037.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14038.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14053.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14071.txt
# Descargado: medex14100.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14101.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14144.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14145.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14156.txt
# Descargado: medex14165.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14167.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14179.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14306.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14324.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14326.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14331.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14346.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex18031.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24055.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24059.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24074.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24077.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24100.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24144.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24146.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24148.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24150.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24151.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24152.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24175.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24191.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32001.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32002.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32003.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32004.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32005.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32006.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32007.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32010.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32011.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32013.txt
# Descargado: medex32015.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32016.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32018.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32019.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32020.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32021.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32022.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32024.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32025.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32026.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32027.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32028.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32029.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32030.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32031.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32032.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32033.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32034.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32036.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32037.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32038.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32039.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32040.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32041.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32042.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32045.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32046.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32047.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32048.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32049.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32050.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32051.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32052.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32053.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32054.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32055.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32057.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32058.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32059.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32061.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32065.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32068.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32069.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32070.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32072.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32073.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32076.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32078.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32084.txt
# Descargado: medex32085.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32086.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32087.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32091.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32093.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32095.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32097.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32098.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32099.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32100.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32101.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32103.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32105.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...
#   warnings.warn(
# Descargado: medex14108.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14134.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14135.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14153.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14161.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14175.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14176.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14186.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14192.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14196.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14319.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14345.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14347.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex14363.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex19129.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24127.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24147.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24166.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24194.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex24196.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32009.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32012.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32014.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32017.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32023.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32043.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32056.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32060.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32062.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32063.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32067.txt
# Descargado: medex32071.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32074.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32077.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32080.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32088.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32089.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32090.txt
# Descargado: medex32092.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32096.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32102.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32104.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32110.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32136.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32138.txt
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Descargado: medex32141.txt
# Descargado: medex32144.txt
#
# Descarga de EXTREMOS completada.
# C:\Users\ALEN\anaconda3\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'smn.conagua.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %% [markdown]
# ## Vamos a convertir los archivos en excel de manera automática

# %%
import pandas as pd
import os

# Definir carpetas
carpeta_txt = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS"
carpeta_excel = os.path.join(carpeta_txt, "DIARIOS_excel")

# Crear la carpeta de salida si no existe
if not os.path.exists(carpeta_excel):
    os.makedirs(carpeta_excel)

# Función para leer y procesar un archivo TXT
def procesar_archivo_txt(ruta_archivo):
    try:
        with open(ruta_archivo, "r", encoding="latin1") as file: #r=read y encoding latin1 para interpretar acentos, ñ, etc.
            lines = file.readlines() #guardar cada linea en una lista
#pasa de: 
            # Juan,25,Zacatecas
            # Ana,30,Guadalajara
            # Luis,22,Monterrey
#a:
#             [
#   "Juan,25,Zacatecas\n",
#   "Ana,30,Guadalajara\n",
#   "Luis,22,Monterrey\n"
# ]


        # Encontrar la línea donde comienzan los datos (evitar encabezados)
        inicio_datos = 0
        for i, line in enumerate(lines): #i es el número de línea, line es el contenido de esa linea
            if "FECHA" in line and "PRECIP" in line:  # Detectar encabezado de la tabla
                inicio_datos = i
                break

        # Leer los datos desde la línea detectada
        df = pd.read_csv(ruta_archivo, skiprows=inicio_datos, delim_whitespace=True)#el delim_whitespace lo utilizamos porque están separados por espacios

        # Eliminar la primera fila que contiene las unidades de medida
        df = df.iloc[1:].copy()

        # Convertir columnas numéricas al tipo adecuado
        columnas_numericas = ["PRECIP", "EVAP", "TMAX", "TMIN"]
        df[columnas_numericas] = df[columnas_numericas].apply(pd.to_numeric, errors='coerce')#convertir texto a número

        return df
    except Exception as e:
        print(f"Error al procesar {ruta_archivo}: {e}")
        return None

# Procesar todos los archivos en la carpeta de TXT
for archivo in os.listdir(carpeta_txt):
    if archivo.endswith(".txt"):
        ruta_txt = os.path.join(carpeta_txt, archivo)

        # Procesar el archivo y obtener el DataFrame
        df_datos = procesar_archivo_txt(ruta_txt)

        if df_datos is not None:
            # Definir la ruta de salida en la carpeta DIARIOS_excel
            nombre_salida = os.path.splitext(archivo)[0] + ".xlsm"
            ruta_excel = os.path.join(carpeta_excel, nombre_salida)

            # Guardar el DataFrame en un archivo Excel
            df_datos.to_excel(ruta_excel, index=False, engine='openpyxl')

            print(f"Archivo guardado: {ruta_excel}")

print("Proceso completado. Todos los archivos han sido convertidos a Excel.")
# Out:
# Archivo guardado: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01003.xlsm
# Archivo guardado: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01006.xlsm
# Archivo guardado: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01008.xlsm
# Archivo guardado: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01009.xlsm
# Archivo guardado: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01010.xlsm
# Archivo guardado: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01011.xlsm
# Archivo guardado: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01012.xlsm
# Archivo guardado: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01013.xlsm
# Archivo guardado: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01015.xlsm
# Archivo guardado: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01017.xlsm
# Archivo guardado: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01020.xlsm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 41>()
#      51             ruta_excel = os.path.join(carpeta_excel, nombre_salida)
#      53             # Guardar el DataFrame en un archivo Excel
# ---> 54             df_datos.to_excel(ruta_excel, index=False, engine='openpyxl')
#      56             print(f"Archivo guardado: {ruta_excel}")
#      58 print("Proceso completado. Todos los archivos han sido convertidos a Excel.")
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py:904, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     901 finally:
#     902     # make sure to close opened file handles
#     903     if need_save:
# --> 904         writer.close()
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1205, in ExcelWriter.close(self)
#    1203 def close(self) -> None:
#    1204     """synonym for save, to make it more file-like"""
# -> 1205     self.save()
#    1206     self.handles.close()
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_openpyxl.py:81, in OpenpyxlWriter.save(self)
#      77 def save(self):
#      78     """
#      79     Save workbook to disk.
#      80     """
# ---> 81     self.book.save(self.handles.handle)
#      82     if "r+" in self.mode and not isinstance(self.handles.handle, mmap.mmap):
#      83         # truncate file to the written content
#      84         self.handles.handle.truncate()
#
# File ~\anaconda3\lib\site-packages\openpyxl\workbook\workbook.py:407, in Workbook.save(self, filename)
#     405 if self.write_only and not self.worksheets:
#     406     self.create_sheet()
# --> 407 save_workbook(self, filename)
#
# File ~\anaconda3\lib\site-packages\openpyxl\writer\excel.py:293, in save_workbook(workbook, filename)
#     291 archive = ZipFile(filename, 'w', ZIP_DEFLATED, allowZip64=True)
#     292 writer = ExcelWriter(workbook, archive)
# --> 293 writer.save()
#     294 return True
#
# File ~\anaconda3\lib\site-packages\openpyxl\writer\excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File ~\anaconda3\lib\site-packages\openpyxl\writer\excel.py:75, in ExcelWriter.write_data(self)
#      72 else:
#      73     archive.writestr(ARC_THEME, theme_xml)
# ---> 75 self._write_worksheets()
#      76 self._write_chartsheets()
#      77 self._write_images()
#
# File ~\anaconda3\lib\site-packages\openpyxl\writer\excel.py:215, in ExcelWriter._write_worksheets(self)
#     212 for idx, ws in enumerate(self.workbook.worksheets, 1):
#     214     ws._id = idx
# --> 215     self.write_worksheet(ws)
#     217     if ws._drawing:
#     218         self._write_drawing(ws._drawing)
#
# File ~\anaconda3\lib\site-packages\openpyxl\writer\excel.py:200, in ExcelWriter.write_worksheet(self, ws)
#     198 else:
#     199     writer = WorksheetWriter(ws)
# --> 200     writer.write()
#     202 ws._rels = writer._rels
#     203 self._archive.write(writer.out, ws.path[1:])
#
# File ~\anaconda3\lib\site-packages\openpyxl\worksheet\_writer.py:359, in WorksheetWriter.write(self)
#     355 """
#     356 High level
#     357 """
#     358 self.write_top()
# --> 359 self.write_rows()
#     360 self.write_tail()
#     361 self.close()
#
# File ~\anaconda3\lib\site-packages\openpyxl\worksheet\_writer.py:125, in WorksheetWriter.write_rows(self)
#     123 with xf.element("sheetData"):
#     124     for row_idx, row in self.rows():
# --> 125         self.write_row(xf, row, row_idx)
#     127 self.xf.send(None)
#
# File ~\anaconda3\lib\site-packages\openpyxl\worksheet\_writer.py:147, in WorksheetWriter.write_row(self, xf, row, row_idx)
#     141 if (
#     142     cell._value is None
#     143     and not cell.has_style
#     144     and not cell._comment
#     145     ):
#     146     continue
# --> 147 write_cell(xf, self.ws, cell, cell.has_style)
#
# File ~\anaconda3\lib\site-packages\openpyxl\cell\_writer.py:81, in lxml_write_cell(xf, worksheet, cell, styled)
#      78     with xf.element("c", attributes):
#      79         return
# ---> 81 with xf.element('c', attributes):
#      82     if cell.data_type == 'f':
#      83         shared_formula = worksheet.formula_attributes.get(cell.coordinate, {})
#
# KeyboardInterrupt:

# %%
import pandas as pd
import os
import xlwings as xw

# Definir carpetas
carpeta_txt = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS"
carpeta_excel = os.path.join(carpeta_txt, "DIARIOS_excel")

# Crear la carpeta de salida si no existe
if not os.path.exists(carpeta_excel):
    os.makedirs(carpeta_excel)

# Función para leer y procesar un archivo TXT
def procesar_archivo_txt(ruta_archivo):
    try:
        with open(ruta_archivo, "r", encoding="latin1") as file:
            lines = file.readlines()

        # Encontrar la línea donde comienzan los datos (evitar encabezados)
        inicio_datos = 0
        for i, line in enumerate(lines):
            if "FECHA" in line and "PRECIP" in line:  # Detectar encabezado de la tabla
                inicio_datos = i
                break

        # Leer los datos desde la línea detectada
        df = pd.read_csv(ruta_archivo, skiprows=inicio_datos, delim_whitespace=True)

        # Eliminar la primera fila que contiene las unidades de medida
        df = df.iloc[1:].copy()

        # Convertir columnas numéricas al tipo adecuado
        columnas_numericas = ["PRECIP", "EVAP", "TMAX", "TMIN"]
        df[columnas_numericas] = df[columnas_numericas].apply(pd.to_numeric, errors='coerce')

        return df
    except Exception as e:
        print(f"Error al procesar {ruta_archivo}: {e}")
        return None

# Procesar todos los archivos en la carpeta de TXT
for archivo in os.listdir(carpeta_txt):
    if archivo.endswith(".txt"):
        ruta_txt = os.path.join(carpeta_txt, archivo)

        # Procesar el archivo y obtener el DataFrame
        df_datos = procesar_archivo_txt(ruta_txt)

        if df_datos is not None:
            # Definir la ruta de salida en la carpeta DIARIOS_excel
            nombre_salida = os.path.splitext(archivo)[0] + ".xlsm"
            ruta_excel = os.path.join(carpeta_excel, nombre_salida)

            # Guardar en un archivo temporal de Excel
            ruta_temporal = ruta_excel.replace(".xlsm", ".xlsx")
            df_datos.to_excel(ruta_temporal, index=False, engine='openpyxl')

            # Convertir el archivo a .xlsm con xlwings
            app = xw.App(visible=False)
            wb = app.books.open(ruta_temporal)
            wb.save(ruta_excel)
            wb.close()
            app.quit()

            # Eliminar el archivo temporal .xlsx
            os.remove(ruta_temporal)

            print(f"Archivo guardado correctamente: {ruta_excel}")

print("Proceso completado. Todos los archivos han sido convertidos a Excel .xlsm correctamente.")
# Out:
# Archivo guardado correctamente: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01003.xlsm
# Archivo guardado correctamente: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01006.xlsm
# Archivo guardado correctamente: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01008.xlsm
# Archivo guardado correctamente: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01009.xlsm
# Archivo guardado correctamente: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01010.xlsm
# Archivo guardado correctamente: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01011.xlsm
# Archivo guardado correctamente: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01012.xlsm
# Archivo guardado correctamente: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01013.xlsm
# Archivo guardado correctamente: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01015.xlsm
# Archivo guardado correctamente: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01017.xlsm
# Archivo guardado correctamente: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\DIARIOS\DIARIOS_excel\dia01020.xlsm
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Input In [5], in <cell line: 42>()
#      59 app = xw.App(visible=False)
#      60 wb = app.books.open(ruta_temporal)
# ---> 61 wb.save(ruta_excel)
#      62 wb.close()
#      63 app.quit()
#
# File ~\anaconda3\lib\site-packages\xlwings\main.py:874, in Book.save(self, path)
#     872     path = utils.fspath(path)
#     873 with self.app.properties(display_alerts=False):
# --> 874     self.impl.save(path)
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:582, in Book.save(self, path)
#     580 alerts_state = self.xl.Application.DisplayAlerts
#     581 self.xl.Application.DisplayAlerts = False
# --> 582 self.xl.SaveAs(os.path.realpath(path), FileFormat=file_format)
#     583 self.xl.Application.DisplayAlerts = alerts_state
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:70, in COMRetryMethodWrapper.__call__(self, *args, **kwargs)
#      68 while True:
#      69     try:
# ---> 70         v = self.__method(*args, **kwargs)
#      71         if isinstance(v, (CDispatch, CoClassBaseClass, DispatchBaseClass)):
#      72             return COMRetryObjectWrapper(v)
#
# File ~\AppData\Local\Temp\gen_py\3.9\00020813-0000-0000-C000-000000000046x0x1x9.py:46832, in _Workbook.SaveAs(self, Filename, FileFormat, Password, WriteResPassword, ReadOnlyRecommended, CreateBackup, AccessMode, ConflictResolution, AddToMru, TextCodepage, TextVisualLayout, Local, WorkIdentity)
#   46829 def SaveAs(self, Filename=defaultNamedNotOptArg, FileFormat=defaultNamedNotOptArg, Password=defaultNamedNotOptArg, WriteResPassword=defaultNamedNotOptArg
#   46830 		, ReadOnlyRecommended=defaultNamedNotOptArg, CreateBackup=defaultNamedNotOptArg, AccessMode=1, ConflictResolution=defaultNamedOptArg, AddToMru=defaultNamedOptArg
#   46831 		, TextCodepage=defaultNamedOptArg, TextVisualLayout=defaultNamedOptArg, Local=defaultNamedOptArg, WorkIdentity=defaultNamedOptArg):
# > 46832 	return self._oleobj_.InvokeTypes(3174, LCID, 1, (24, 0), ((12, 17), (12, 17), (12, 17), (12, 17), (12, 17), (12, 17), (3, 49), (12, 17), (12, 17), (12, 17), (12, 17), (12, 17), (12, 17)),Filename
#   46833 		, FileFormat, Password, WriteResPassword, ReadOnlyRecommended, CreateBackup
#   46834 		, AccessMode, ConflictResolution, AddToMru, TextCodepage, TextVisualLayout
#   46835 		, Local, WorkIdentity)
#
# com_error: (-2147352567, 'Ocurrió una excepción.', (0, 'Microsoft Excel', 'No se puede obtener acceso a "dia01023.xlsm".', 'xlmain11.chm', 0, -2146827284), None)

# %% [markdown]
# # Opción 1 mensuales

# %%
import os
import pandas as pd
import xlwings as xw

# Definir carpetas
carpeta_txt = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES"
carpeta_excel = os.path.join(carpeta_txt, "MENSUALES_excel1")

# Crear la carpeta de salida si no existe
if not os.path.exists(carpeta_excel):
    os.makedirs(carpeta_excel)

# Nombres de las tablas identificadas
nombres_tablas = [
    "LLUVIA MÁXIMA 24 H.",
    "LLUVIA TOTAL MENSUAL",
    "EVAPORACIÓN MENSUAL",
    "TEMPERATURA MÁXIMA PROMEDIO",
    "TEMPERATURA MÁXIMA EXTREMA",
    "TEMPERATURA MÍNIMA PROMEDIO",
    "TEMPERATURA MÍNIMA EXTREMA",
    "TEMPERATURA MEDIA MENSUAL"
]

# Procesar archivos TXT
for archivo_txt in os.listdir(carpeta_txt):
    if archivo_txt.endswith(".txt"):
        ruta_txt = os.path.join(carpeta_txt, archivo_txt)
        with open(ruta_txt, "r", encoding="utf-8") as file:
            lineas = file.readlines()
        
        tablas = {}
        tabla_actual = None
        datos_actuales = []
        
        for linea in lineas:
            linea = linea.strip()
            if linea in nombres_tablas:
                if tabla_actual and datos_actuales:
                    tablas[tabla_actual] = pd.DataFrame(datos_actuales)
                tabla_actual = linea
                datos_actuales = []
            elif tabla_actual and linea:
                datos_actuales.append(linea.split())
        
        if tabla_actual and datos_actuales:
            tablas[tabla_actual] = pd.DataFrame(datos_actuales)

        # Crear archivo XLSM temporal
        nombre_excel = archivo_txt.replace(".txt", ".xlsm")
        ruta_excel = os.path.join(carpeta_excel, nombre_excel)
        
        with pd.ExcelWriter(ruta_excel, engine='openpyxl') as writer:
            for nombre_tabla, df in tablas.items():
                df.to_excel(writer, sheet_name=nombre_tabla[:31], index=False, header=False)

        # Convertir a XLSM con xlwings
        app = xw.App(visible=False)
        wb = app.books.open(ruta_excel)
        wb.save()
        wb.close()
        app.quit()
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:496, in Books.__call__(self, name_or_index)
#     495 try:
# --> 496     return Book(xl=self.xl(name_or_index))
#     497 except pywintypes.com_error:
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:160, in COMRetryObjectWrapper.__call__(self, *args, **kwargs)
#     159 try:
# --> 160     v = self._inner(*args, **kwargs)
#     161     if isinstance(v, (CDispatch, CoClassBaseClass, DispatchBaseClass)):
#
# File ~\AppData\Local\Temp\gen_py\3.9\00020813-0000-0000-C000-000000000046x0x1x9.py:41339, in Workbooks.__call__(self, Index)
#   41338 def __call__(self, Index=defaultNamedNotOptArg):
# > 41339 	ret = self._oleobj_.InvokeTypes(0, LCID, 2, (13, 0), ((12, 1),),Index
#   41340 		)
#   41341 	if ret is not None:
#   41342 		# See if this IUnknown is really an IDispatch
#
# com_error: (-2147352567, 'Ocurrió una excepción.', (0, None, None, None, 0, -2147352565), None)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\xlwings\main.py:4277, in Books.open(self, fullname, update_links, read_only, format, password, write_res_password, ignore_read_only_recommended, origin, delimiter, editable, notify, converter, add_to_mru, local, corrupt_load)
#    4276 try:
# -> 4277     impl = self.impl(name)
#    4278     if not os.path.samefile(impl.fullname, fullname):
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:498, in Books.__call__(self, name_or_index)
#     497 except pywintypes.com_error:
# --> 498     raise KeyError(name_or_index)
#
# KeyError: 'mes01003.xlsm'
#
# During handling of the above exception, another exception occurred:
#
# com_error                                 Traceback (most recent call last)
# Input In [13], in <cell line: 26>()
#      57 # Convertir a XLSM con xlwings
#      58 app = xw.App(visible=False)
# ---> 59 wb = app.books.open(ruta_excel)
#      60 wb.save()
#      61 wb.close()
#
# File ~\anaconda3\lib\site-packages\xlwings\main.py:4283, in Books.open(self, fullname, update_links, read_only, format, password, write_res_password, ignore_read_only_recommended, origin, delimiter, editable, notify, converter, add_to_mru, local, corrupt_load)
#    4279         raise ValueError(
#    4280             "Cannot open two workbooks named '%s', even if they are saved in different locations." % name
#    4281         )
#    4282 except KeyError:
# -> 4283     impl = self.impl.open(fullname, update_links, read_only, format, password, write_res_password,
#    4284                           ignore_read_only_recommended, origin, delimiter, editable, notify, converter,
#    4285                           add_to_mru, local, corrupt_load)
#    4286 return Book(impl=impl)
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:514, in Books.open(self, fullname, update_links, read_only, format, password, write_res_password, ignore_read_only_recommended, origin, delimiter, editable, notify, converter, add_to_mru, local, corrupt_load)
#     512     update_links = UpdateLinks.xlUpdateLinksAlways
#     513 # Workbooks.Open params are position only on pywin32
# --> 514 return Book(xl=self.xl.Open(fullname, update_links, read_only, format, password, write_res_password,
#     515                             ignore_read_only_recommended, origin, delimiter, editable, notify, converter,
#     516                             add_to_mru, local, corrupt_load))
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:70, in COMRetryMethodWrapper.__call__(self, *args, **kwargs)
#      68 while True:
#      69     try:
# ---> 70         v = self.__method(*args, **kwargs)
#      71         if isinstance(v, (CDispatch, CoClassBaseClass, DispatchBaseClass)):
#      72             return COMRetryObjectWrapper(v)
#
# File ~\AppData\Local\Temp\gen_py\3.9\00020813-0000-0000-C000-000000000046x0x1x9.py:41216, in Workbooks.Open(self, Filename, UpdateLinks, ReadOnly, Format, Password, WriteResPassword, IgnoreReadOnlyRecommended, Origin, Delimiter, Editable, Notify, Converter, AddToMru, Local, CorruptLoad)
#   41212 def Open(self, Filename=defaultNamedNotOptArg, UpdateLinks=defaultNamedOptArg, ReadOnly=defaultNamedOptArg, Format=defaultNamedOptArg
#   41213 		, Password=defaultNamedOptArg, WriteResPassword=defaultNamedOptArg, IgnoreReadOnlyRecommended=defaultNamedOptArg, Origin=defaultNamedOptArg, Delimiter=defaultNamedOptArg
#   41214 		, Editable=defaultNamedOptArg, Notify=defaultNamedOptArg, Converter=defaultNamedOptArg, AddToMru=defaultNamedOptArg, Local=defaultNamedOptArg
#   41215 		, CorruptLoad=defaultNamedOptArg):
# > 41216 	ret = self._oleobj_.InvokeTypes(1923, LCID, 1, (13, 0), ((8, 1), (12, 17), (12, 17), (12, 17), (12, 17), (12, 17), (12, 17), (12, 17), (12, 17), (12, 17), (12, 17), (12, 17), (12, 17), (12, 17), (12, 17)),Filename
#   41217 		, UpdateLinks, ReadOnly, Format, Password, WriteResPassword
#   41218 		, IgnoreReadOnlyRecommended, Origin, Delimiter, Editable, Notify
#   41219 		, Converter, AddToMru, Local, CorruptLoad)
#   41220 	if ret is not None:
#   41221 		# See if this IUnknown is really an IDispatch
#   41222 		try:
#
# com_error: (-2147352567, 'Ocurrió una excepción.', (0, 'Microsoft Excel', "Excel no puede abrir el archivo 'mes01003.xlsm' porque el formato o la extensión no son válidos. Compruebe que el archivo no se ha dañado y que la extensión y el formato del archivo coinciden.", 'xlmain11.chm', 0, -2146827284), None)

# %%
import pandas as pd
import os

# Ruta de la carpeta donde se guardará el archivo
ruta_carpeta = "MENSUALES_excel2"
os.makedirs(ruta_carpeta, exist_ok=True)

# Ruta del archivo de salida
ruta_excel = os.path.join(ruta_carpeta, "datos_mensuales.xlsx")

# Definir nombres de las tablas
nombres_tablas = [
    "LLUVIA MÁXIMA 24 H.",
    "LLUVIA TOTAL MENSUAL",
    "EVAPORACIÓN MENSUAL",
    "TEMPERATURA MÁXIMA PROMEDIO",
    "TEMPERATURA MÁXIMA EXTREMA",
    "TEMPERATURA MÍNIMA PROMEDIO",
    "TEMPERATURA MÍNIMA EXTREMA",
    "TEMPERATURA MEDIA MENSUAL"
]

# Simulación de lectura y procesamiento de datos (ajustar con los datos reales)
datos_tablas = []
for nombre in nombres_tablas:
    # Generar datos de ejemplo (Reemplazar con los datos reales extraídos)
    df = pd.DataFrame({
        "AÑO": list(range(2000, 2010)),
        "ENE": [round(i * 1.1, 1) for i in range(10)],
        "FEB": [round(i * 1.2, 1) for i in range(10)],
        "MAR": [round(i * 1.3, 1) for i in range(10)],
        "ABR": [round(i * 1.4, 1) for i in range(10)],
        "MAY": [round(i * 1.5, 1) for i in range(10)],
        "JUN": [round(i * 1.6, 1) for i in range(10)],
        "JUL": [round(i * 1.7, 1) for i in range(10)],
        "AGO": [round(i * 1.8, 1) for i in range(10)],
        "SEP": [round(i * 1.9, 1) for i in range(10)],
        "OCT": [round(i * 2.0, 1) for i in range(10)],
        "NOV": [round(i * 2.1, 1) for i in range(10)],
        "DIC": [round(i * 2.2, 1) for i in range(10)],
        "ACUM": [round(i * 2.3, 1) for i in range(10)],
        "PROM": [round(i * 2.4, 1) for i in range(10)],
        "MESES": [12] * 10
    })
    
    # Agregar columna con el nombre de la tabla
    df["TIPO DE DATO"] = nombre
    datos_tablas.append(df)

# Concatenar todas las tablas en una sola
df_final = pd.concat(datos_tablas, ignore_index=True)

# Guardar en Excel en una sola hoja
df_final.to_excel(ruta_excel, sheet_name="Datos_Mensuales", index=False)

print(f"Archivo guardado en: {ruta_excel}")
# Out:
# Archivo guardado en: MENSUALES_excel2\datos_mensuales.xlsx

# %%
import os
import pandas as pd
import xlwings as xw
import numpy as np

# Definir rutas de entrada y salida
carpeta_txt = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES"
carpeta_excel1 = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1"
carpeta_excel2 = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel2"

# Crear carpetas de salida si no existen
os.makedirs(carpeta_excel1, exist_ok=True)
os.makedirs(carpeta_excel2, exist_ok=True)

# Definir las secciones de tablas
secciones = [
    "LLUVIA MÁXIMA 24 H.", "LLUVIA TOTAL MENSUAL", "EVAPORACIÓN MENSUAL",
    "TEMPERATURA MÁXIMA PROMEDIO", "TEMPERATURA MÁXIMA EXTREMA", 
    "TEMPERATURA MÍNIMA PROMEDIO", "TEMPERATURA MÍNIMA EXTREMA", "TEMPERATURA MEDIA MENSUAL"
]

def leer_archivo_txt(ruta):
    """Leer un archivo de texto y extraer su contenido"""
    with open(ruta, 'r', encoding='utf-8') as file:
        lineas = file.readlines()
    return lineas

def extraer_tablas(lineas):
    """Extraer datos de tablas basadas en las secciones identificadas"""
    tablas = {}
    nombre_tabla = None
    datos = []
    columnas = []
    
    for linea in lineas:
        linea = linea.strip()
        if linea in secciones:
            if nombre_tabla and datos:
                df = pd.DataFrame(datos, columns=columnas).replace('', np.nan)
                tablas[nombre_tabla] = df
            nombre_tabla = linea
            datos = []
            columnas = []
        elif nombre_tabla and linea:
            valores = linea.split()
            if not columnas:
                columnas = valores  # Asignar la primera fila como nombres de columnas
            else:
                while len(valores) < len(columnas):
                    valores.append(np.nan)  # Rellenar con NaN para mantener la alineación
                datos.append(valores)
    
    if nombre_tabla and datos:
        df = pd.DataFrame(datos, columns=columnas).replace('', np.nan)
        tablas[nombre_tabla] = df
    
    return tablas

def opcion_1(txt_files):
    """Cada tabla en una hoja separada"""
    for archivo in txt_files:
        ruta_txt = os.path.join(carpeta_txt, archivo)
        lineas = leer_archivo_txt(ruta_txt)
        tablas = extraer_tablas(lineas)
        
        if tablas:
            ruta_excel = os.path.join(carpeta_excel1, archivo.replace('.txt', '.xlsm'))
            wb = xw.Book()
            for nombre, df in tablas.items():
                sheet = wb.sheets.add(name=nombre[:31])
                sheet.range("A1").value = [df.columns.tolist()] + df.fillna('').values.tolist()
            wb.save(ruta_excel)
            wb.close()

def opcion_2(txt_files):
    """Todas las tablas en una sola hoja con columna de tipo de dato"""
    for archivo in txt_files:
        ruta_txt = os.path.join(carpeta_txt, archivo)
        lineas = leer_archivo_txt(ruta_txt)
        tablas = extraer_tablas(lineas)
        
        if tablas:
            ruta_excel = os.path.join(carpeta_excel2, archivo.replace('.txt', '.xlsm'))
            wb = xw.Book()
            sheet = wb.sheets.add(name="Datos Combinados")
            df_final = pd.DataFrame()
            
            for nombre, df in tablas.items():
                df.insert(0, "Tipo de Dato", nombre)
                while df.shape[1] < len(df.columns):
                    df[df.columns[df.shape[1]]] = np.nan  # Asegurar alineación con NaN
                df_final = pd.concat([df_final, df], ignore_index=True)
            
            sheet.range("A1").value = [df_final.columns.tolist()] + df_final.fillna('').values.tolist()
            wb.save(ruta_excel)
            wb.close()

# Obtener archivos de la carpeta de textos
txt_files = [f for f in os.listdir(carpeta_txt) if f.endswith('.txt')]

# Ejecutar ambas opciones
opcion_1(txt_files)
opcion_2(txt_files)

print("Conversión completada.")
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Input In [16], in <cell line: 102>()
#      99 txt_files = [f for f in os.listdir(carpeta_txt) if f.endswith('.txt')]
#     101 # Ejecutar ambas opciones
# --> 102 opcion_1(txt_files)
#     103 opcion_2(txt_files)
#     105 print("Conversión completada.")
#
# Input In [16], in opcion_1(txt_files)
#      66 if tablas:
#      67     ruta_excel = os.path.join(carpeta_excel1, archivo.replace('.txt', '.xlsm'))
# ---> 68     wb = xw.Book()
#      69     for nombre, df in tablas.items():
#      70         sheet = wb.sheets.add(name=nombre[:31])
#
# File ~\anaconda3\lib\site-packages\xlwings\main.py:692, in Book.__init__(self, fullname, update_links, read_only, format, password, write_res_password, ignore_read_only_recommended, origin, delimiter, editable, notify, converter, add_to_mru, local, corrupt_load, impl)
#     689 else:
#     690     # Open Excel if necessary and create a new workbook
#     691     if apps.active:
# --> 692         impl = apps.active.books.add().impl
#     693     else:
#     694         app = App()
#
# File ~\anaconda3\lib\site-packages\xlwings\main.py:4248, in Books.add(self)
#    4244 def add(self):
#    4245     """
#    4246     Creates a new Book. The new Book becomes the active Book. Returns a Book object.
#    4247     """
# -> 4248     return Book(impl=self.impl.add())
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:504, in Books.add(self)
#     503 def add(self):
# --> 504     return Book(xl=self.xl.Add())
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:70, in COMRetryMethodWrapper.__call__(self, *args, **kwargs)
#      68 while True:
#      69     try:
# ---> 70         v = self.__method(*args, **kwargs)
#      71         if isinstance(v, (CDispatch, CoClassBaseClass, DispatchBaseClass)):
#      72             return COMRetryObjectWrapper(v)
#
# File ~\AppData\Local\Temp\gen_py\3.9\00020813-0000-0000-C000-000000000046x0x1x9.py:41175, in Workbooks.Add(self, Template)
#   41174 def Add(self, Template=defaultNamedOptArg):
# > 41175 	ret = self._oleobj_.InvokeTypes(181, LCID, 1, (13, 0), ((12, 17),),Template
#   41176 		)
#   41177 	if ret is not None:
#   41178 		# See if this IUnknown is really an IDispatch
#   41179 		try:
#
# com_error: (-2147352567, 'Ocurrió una excepción.', (0, 'Microsoft Excel', 'Error en el método Add de la clase Workbooks.', 'xlmain11.chm', 0, -2146827284), None)

# %%
import os
import pandas as pd
import xlwings as xw

# Definir rutas de entrada y salida
carpeta_txt = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES"
carpeta_excel1 = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1"
carpeta_excel2 = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel2"

# Crear carpetas de salida si no existen
os.makedirs(carpeta_excel1, exist_ok=True)
os.makedirs(carpeta_excel2, exist_ok=True)

# Definir las secciones de tablas
secciones = [
    "LLUVIA MÁXIMA 24 H.", "LLUVIA TOTAL MENSUAL", "EVAPORACIÓN MENSUAL",
    "TEMPERATURA MÁXIMA PROMEDIO", "TEMPERATURA MÁXIMA EXTREMA", 
    "TEMPERATURA MÍNIMA PROMEDIO", "TEMPERATURA MÍNIMA EXTREMA", "TEMPERATURA MEDIA MENSUAL"
]

def txt_a_xlsx(ruta_txt, ruta_xlsx):
    """Convierte un archivo TXT a XLSX sin modificar su estructura."""
    with open(ruta_txt, 'r', encoding='utf-8') as file:
        lineas = file.readlines()
    
    df = pd.DataFrame([line.strip().split() for line in lineas])
    df.to_excel(ruta_xlsx, index=False, header=False)

def identificar_tablas(ruta_xlsx):
    """Identifica las tablas dentro del archivo XLSX y las separa correctamente."""
    df = pd.read_excel(ruta_xlsx, header=None)
    tablas = {}
    nombre_tabla = None
    datos = []
    
    for _, row in df.iterrows():
        row_data = row.dropna().astype(str).tolist()
        if not row_data:
            continue
        if row_data[0] in secciones:
            if nombre_tabla and datos:
                tablas[nombre_tabla] = pd.DataFrame(datos)
            nombre_tabla = row_data[0]
            datos = []
        else:
            datos.append(row_data)
    
    if nombre_tabla and datos:
        tablas[nombre_tabla] = pd.DataFrame(datos)
    
    if not tablas:
        print(f"No se encontraron tablas en {ruta_xlsx}. Verifica si los datos están correctamente estructurados.")
    
    return tablas

def guardar_xlsx(tablas, ruta_xlsx, opcion):
    """Guarda los datos en XLSX, opción 1 en hojas separadas, opción 2 en una sola hoja."""
    with pd.ExcelWriter(ruta_xlsx, engine='xlsxwriter') as writer:
        if opcion == 1:
            for nombre, df in tablas.items():
                if not df.empty:
                    df.to_excel(writer, sheet_name=nombre[:31], index=False, header=False)
        else:
            if not tablas:
                print(f"No hay datos para guardar en {ruta_xlsx}")
                return
            df_lista = [df.assign(Tipo=nombre) for nombre, df in tablas.items() if not df.empty]
            if df_lista:
                df_final = pd.concat(df_lista, ignore_index=True)
                df_final.to_excel(writer, sheet_name="Datos Combinados", index=False, header=False)
            else:
                print(f"No hay datos válidos para concatenar en {ruta_xlsx}")

def convertir_xlsx_a_xlsm(ruta_xlsx, ruta_xlsm):
    """Convierte un archivo XLSX a XLSM usando xlwings."""
    app = xw.App(visible=False)
    wb = app.books.open(ruta_xlsx)
    wb.save(ruta_xlsm)
    wb.close()
    app.quit()

# Procesar los archivos TXT y generar XLSX
for archivo in os.listdir(carpeta_txt):
    if archivo.endswith('.txt'):
        ruta_txt = os.path.join(carpeta_txt, archivo)
        ruta_xlsx = os.path.join(carpeta_excel1, archivo.replace('.txt', '.xlsx'))
        txt_a_xlsx(ruta_txt, ruta_xlsx)
        
        tablas = identificar_tablas(ruta_xlsx)
        
        if not tablas:
            print(f"No se procesaron tablas en {ruta_xlsx}. Verifica el contenido del archivo.")
            continue
        
        ruta_xlsx_opcion1 = os.path.join(carpeta_excel1, archivo.replace('.txt', '_opcion1.xlsx'))
        ruta_xlsx_opcion2 = os.path.join(carpeta_excel2, archivo.replace('.txt', '_opcion2.xlsx'))
        
        guardar_xlsx(tablas, ruta_xlsx_opcion1, opcion=1)
        guardar_xlsx(tablas, ruta_xlsx_opcion2, opcion=2)
        
        # Convertir XLSX a XLSM si los archivos existen
        if os.path.exists(ruta_xlsx_opcion1):
            convertir_xlsx_a_xlsm(ruta_xlsx_opcion1, ruta_xlsx_opcion1.replace('.xlsx', '.xlsm'))
        if os.path.exists(ruta_xlsx_opcion2):
            convertir_xlsx_a_xlsm(ruta_xlsx_opcion2, ruta_xlsx_opcion2.replace('.xlsx', '.xlsm'))

print("Conversión completada.")
# Out:
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01003.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01003.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01006.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01006.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01008.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01008.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01009.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01009.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01010.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01010.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01011.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01011.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01012.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01012.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01013.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01013.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01015.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01015.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01017.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01017.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01020.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01020.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01023.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01023.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01026.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01026.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01028.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01028.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01029.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01029.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01031.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01031.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01032.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01032.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01033.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01033.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01045.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01045.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01046.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01046.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01078.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01078.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01081.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01081.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01084.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01084.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01088.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01088.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01091.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01091.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01095.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01095.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01103.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01103.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes05004.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes05004.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes05175.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes05175.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10032.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10032.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10047.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10047.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10057.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10057.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10067.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10067.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10070.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10070.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10074.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10074.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10081.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10081.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10088.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10088.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10099.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10099.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10135.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10135.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10172.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10172.xlsx. Verifica el contenido del archivo.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5587, in NDFrame.__setattr__(self, name, value)
#    5586 try:
# -> 5587     object.__getattribute__(self, name)
#    5588     return object.__setattr__(self, name, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:638, in Series.name(self)
#     592 """
#     593 Return the name of the Series.
#     594
#    (...)
#     636 'Even Numbers'
#     637 """
# --> 638 return self._name
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute '_name'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [25], in <cell line: 83>()
#      86 ruta_xlsx = os.path.join(carpeta_excel1, archivo.replace('.txt', '.xlsx'))
#      87 txt_a_xlsx(ruta_txt, ruta_xlsx)
# ---> 89 tablas = identificar_tablas(ruta_xlsx)
#      91 if not tablas:
#      92     print(f"No se procesaron tablas en {ruta_xlsx}. Verifica el contenido del archivo.")
#
# Input In [25], in identificar_tablas(ruta_xlsx)
#      34 datos = []
#      36 for _, row in df.iterrows():
# ---> 37     row_data = row.dropna().astype(str).tolist()
#      38     if not row_data:
#      39         continue
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5378, in Series.dropna(self, axis, inplace, how)
#    5375 self._get_axis_number(axis or 0)
#    5377 if self._can_hold_na:
# -> 5378     result = remove_na_arraylike(self)
#    5379     if inplace:
#    5380         self._update_inplace(result)
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:622, in remove_na_arraylike(arr)
#     620     return arr[notna(arr)]
#     621 else:
# --> 622     return arr[notna(np.asarray(arr))]
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:982, in Series.__getitem__(self, key)
#     980     key = check_bool_indexer(self.index, key)
#     981     key = np.asarray(key, dtype=bool)
# --> 982     return self._get_values(key)
#     984 return self._get_with(key)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1045, in Series._get_values(self, indexer)
#    1043 try:
#    1044     new_mgr = self._mgr.getitem_mgr(indexer)
# -> 1045     return self._constructor(new_mgr).__finalize__(self)
#    1046 except ValueError:
#    1047     # mpl compat if we look up e.g. ser[:, np.newaxis];
#    1048     #  see tests.series.timeseries.test_mpl_compat_hack
#    1049     # the asarray is needed to avoid returning a 2D DatetimeArray
#    1050     return np.asarray(self._values[indexer])
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:345, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     343         object.__setattr__(self, "_name", name)
#     344     else:
# --> 345         self.name = name
#     346     return
#     348 # we are called internally, so short-circuit
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5589, in NDFrame.__setattr__(self, name, value)
#    5587     object.__getattribute__(self, name)
#    5588     return object.__setattr__(self, name, value)
# -> 5589 except AttributeError:
#    5590     pass
#    5592 # if this fails, go on to more involved attribute setting
#    5593 # (note that this matches __getattr__, above).
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
import xlwings as xw
import re

# Definir rutas de entrada y salida
carpeta_txt = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES"
carpeta_excel1 = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1"
carpeta_excel2 = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel2"

# Crear carpetas de salida si no existen
os.makedirs(carpeta_excel1, exist_ok=True)
os.makedirs(carpeta_excel2, exist_ok=True)

# Definir las secciones de tablas
secciones = [
    "LLUVIA MÁXIMA 24 H.", "LLUVIA TOTAL MENSUAL", "EVAPORACIÓN MENSUAL",
    "TEMPERATURA MÁXIMA PROMEDIO", "TEMPERATURA MÁXIMA EXTREMA", 
    "TEMPERATURA MÍNIMA PROMEDIO", "TEMPERATURA MÍNIMA EXTREMA", "TEMPERATURA MEDIA MENSUAL"
]

def limpiar_linea(linea):
    """Limpia una línea del archivo TXT asegurando que los espacios sean consistentes."""
    linea = re.sub(r'\s+', ' ', linea.strip())  # Reemplaza múltiples espacios con uno solo
    return linea.split(' ')

def txt_a_xlsx(ruta_txt, ruta_xlsx):
    """Convierte un archivo TXT a XLSX sin modificar su estructura pero asegurando buena alineación."""
    with open(ruta_txt, 'r', encoding='utf-8') as file:
        lineas = file.readlines()
    
    df = pd.DataFrame([limpiar_linea(line) for line in lineas])
    df.to_excel(ruta_xlsx, index=False, header=False)

def identificar_tablas(ruta_xlsx):
    """Identifica las tablas dentro del archivo XLSX asegurando una alineación adecuada."""
    df = pd.read_excel(ruta_xlsx, header=None, dtype=str)
    df.fillna('', inplace=True)
    tablas = {}
    nombre_tabla = None
    datos = []
    
    for _, row in df.iterrows():
        row_data = row.tolist()
        row_data = [str(x).strip() for x in row_data if x.strip() != '']  # Eliminar espacios innecesarios
        
        if not row_data:
            continue
        
        if row_data[0] in secciones:
            if nombre_tabla and datos:
                tablas[nombre_tabla] = pd.DataFrame(datos)
            nombre_tabla = row_data[0]
            datos = []
        else:
            datos.append(row_data)
    
    if nombre_tabla and datos:
        tablas[nombre_tabla] = pd.DataFrame(datos)
    
    if not tablas:
        print(f"No se encontraron tablas en {ruta_xlsx}. Verifica si los datos están correctamente estructurados.")
    
    return tablas

def guardar_xlsx(tablas, ruta_xlsx, opcion):
    """Guarda los datos en XLSX, opción 1 en hojas separadas, opción 2 en una sola hoja."""
    with pd.ExcelWriter(ruta_xlsx, engine='xlsxwriter') as writer:
        if opcion == 1:
            for nombre, df in tablas.items():
                if not df.empty:
                    df.to_excel(writer, sheet_name=nombre[:31], index=False, header=False)
        else:
            if not tablas:
                print(f"No hay datos para guardar en {ruta_xlsx}")
                return
            df_lista = [df.assign(Tipo=nombre) for nombre, df in tablas.items() if not df.empty]
            if df_lista:
                df_final = pd.concat(df_lista, ignore_index=True)
                df_final.to_excel(writer, sheet_name="Datos Combinados", index=False, header=False)
            else:
                print(f"No hay datos válidos para concatenar en {ruta_xlsx}")

def convertir_xlsx_a_xlsm(ruta_xlsx, ruta_xlsm):
    """Convierte un archivo XLSX a XLSM usando xlwings."""
    app = xw.App(visible=False)
    wb = app.books.open(ruta_xlsx)
    wb.save(ruta_xlsm)
    wb.close()
    app.quit()

# Procesar los archivos TXT y generar XLSX
for archivo in os.listdir(carpeta_txt):
    if archivo.endswith('.txt'):
        ruta_txt = os.path.join(carpeta_txt, archivo)
        ruta_xlsx = os.path.join(carpeta_excel1, archivo.replace('.txt', '.xlsx'))
        txt_a_xlsx(ruta_txt, ruta_xlsx)
        
        tablas = identificar_tablas(ruta_xlsx)
        
        if not tablas:
            print(f"No se procesaron tablas en {ruta_xlsx}. Verifica el contenido del archivo.")
            continue
        
        ruta_xlsx_opcion1 = os.path.join(carpeta_excel1, archivo.replace('.txt', '_opcion1.xlsx'))
        ruta_xlsx_opcion2 = os.path.join(carpeta_excel2, archivo.replace('.txt', '_opcion2.xlsx'))
        
        guardar_xlsx(tablas, ruta_xlsx_opcion1, opcion=1)
        guardar_xlsx(tablas, ruta_xlsx_opcion2, opcion=2)
        
        # Convertir XLSX a XLSM si los archivos existen
        if os.path.exists(ruta_xlsx_opcion1):
            convertir_xlsx_a_xlsm(ruta_xlsx_opcion1, ruta_xlsx_opcion1.replace('.xlsx', '.xlsm'))
        if os.path.exists(ruta_xlsx_opcion2):
            convertir_xlsx_a_xlsm(ruta_xlsx_opcion2, ruta_xlsx_opcion2.replace('.xlsx', '.xlsm'))

print("Conversión completada.")
# Out:
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01003.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01003.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01006.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01006.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01008.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01008.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01009.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01009.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01010.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01010.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01011.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01011.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01012.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01012.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01013.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01013.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01015.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01015.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01017.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01017.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01020.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01020.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01023.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01023.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01026.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01026.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01028.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01028.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01029.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01029.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01031.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01031.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01032.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01032.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01033.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01033.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01045.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01045.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01046.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01046.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01078.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01078.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01081.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01081.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01084.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01084.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01088.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01088.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01091.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01091.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01095.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01095.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01103.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes01103.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes05004.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes05004.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes05175.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes05175.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10032.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10032.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10047.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10047.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10057.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10057.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10067.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10067.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10070.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10070.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10074.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10074.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10081.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10081.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10088.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10088.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10099.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10099.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10135.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10135.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10172.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes10172.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes11045.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes11045.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14025.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14025.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14026.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14026.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14032.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14032.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14037.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14037.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14038.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14038.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14053.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14053.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14069.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14069.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14071.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14071.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14098.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14098.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14100.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14100.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14101.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14101.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14103.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14103.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14108.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14108.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14134.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14134.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14135.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14135.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14144.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14144.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14145.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14145.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14153.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14153.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14156.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14156.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14165.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14165.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14167.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14167.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14175.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14175.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14176.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14176.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14179.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14179.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14186.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14186.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14192.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14192.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14196.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14196.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14306.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14306.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14319.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14319.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14324.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14324.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14326.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14326.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14331.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14331.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14345.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14345.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14346.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes14346.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes18031.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes18031.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes19129.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes19129.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24055.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24055.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24059.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24059.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24074.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24074.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24077.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24077.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24100.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24100.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24144.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24144.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24146.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24146.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24148.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24148.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24150.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24150.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24151.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24151.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24152.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24152.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24166.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24166.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24175.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24175.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24191.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24191.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24194.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24194.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24196.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes24196.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32001.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32001.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32002.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32002.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32003.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32003.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32004.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32004.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32005.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32005.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32006.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32006.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32007.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32007.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32009.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32009.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32010.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32010.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32011.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32011.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32012.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32012.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32013.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32013.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32015.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32015.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32016.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32016.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32017.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32017.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32018.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32018.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32019.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32019.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32020.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32020.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32021.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32021.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32022.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32022.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32023.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32023.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32024.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32024.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32025.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32025.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32026.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32026.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32027.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32027.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32028.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32028.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32029.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32029.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32030.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32030.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32031.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32031.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32032.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32032.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32033.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32033.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32034.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32034.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32036.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32036.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32037.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32037.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32038.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32038.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32039.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32039.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32040.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32040.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32041.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32041.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32042.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32042.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32043.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32043.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32045.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32045.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32046.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32046.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32047.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32047.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32048.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32048.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32049.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32049.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32050.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32050.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32051.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32051.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32052.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32052.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32053.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32053.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32054.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32054.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32055.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32055.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32056.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32056.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32057.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32057.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32058.xlsx. Verifica si los datos están correctamente estructurados.
# ...
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32109.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32110.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32110.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32111.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32111.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32112.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32112.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32113.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32113.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32114.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32114.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32115.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32115.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32116.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32116.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32117.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32117.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32118.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32118.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32119.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32119.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32120.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32120.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32121.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32121.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32122.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32122.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32123.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32123.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32124.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32124.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32125.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32125.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32126.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32126.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32127.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32127.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32129.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32129.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32130.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32130.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32131.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32131.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32132.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32132.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32133.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32133.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32134.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32134.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32135.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32135.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32136.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32136.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32137.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32137.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32138.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32138.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32139.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32139.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32140.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32140.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32141.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32141.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32142.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32142.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32143.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32143.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32144.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32144.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32171.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32171.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32172.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32172.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32173.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32173.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32174.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32174.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32176.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32176.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32177.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32177.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32179.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32179.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32180.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32180.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32184.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32184.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32186.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32186.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32187.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32187.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32188.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32188.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32189.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32189.xlsx. Verifica el contenido del archivo.
# No se encontraron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32191.xlsx. Verifica si los datos están correctamente estructurados.
# No se procesaron tablas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel1\mes32191.xlsx. Verifica el contenido del archivo.
# Conversión completada.

# %%
import pandas as pd
import os

# Definir carpetas
carpeta_txt = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES"
carpeta_excel = os.path.join(carpeta_txt, "MENSUALES_excel")

# Crear la carpeta de salida si no existe
if not os.path.exists(carpeta_excel):
    os.makedirs(carpeta_excel)

# Función para leer y procesar un archivo TXT
def procesar_archivo_txt(ruta_archivo):
    try:
        with open(ruta_archivo, "r", encoding="latin1") as file:
            lines = file.readlines()

        # Encontrar la línea donde comienzan los datos (evitar encabezados)
        inicio_datos = 0
        for i, line in enumerate(lines):
            if "AÑO" in line and "ENE" in line:  # Detectar encabezado de la tabla
                inicio_datos = i
                break

        # Leer los datos desde la línea detectada
        df = pd.read_csv(ruta_archivo, skiprows=inicio_datos, delim_whitespace=True)

        # Eliminar la primera fila que contiene las unidades de medida
        df = df.iloc[1:].copy()

        # Convertir columnas numéricas al tipo adecuado
        columnas_numericas = ["AÑO", "ENE", "FEB", "MAR", "ABR", "MAY", "JUN", "JUL", "AGO", "SEP", "OCT", "NOV", "DIC"]
        df[columnas_numericas] = df[columnas_numericas].apply(pd.to_numeric, errors='coerce')

        return df
    except Exception as e:
        print(f"Error al procesar {ruta_archivo}: {e}")
        return None

# Procesar todos los archivos en la carpeta de TXT
for archivo in os.listdir(carpeta_txt):
    if archivo.endswith(".txt"):
        ruta_txt = os.path.join(carpeta_txt, archivo)

        # Procesar el archivo y obtener el DataFrame
        df_datos = procesar_archivo_txt(ruta_txt)

        if df_datos is not None:
            # Definir la ruta de salida en la carpeta MENSUALES_excel
            nombre_salida = os.path.splitext(archivo)[0] + ".xlsm"
            ruta_excel = os.path.join(carpeta_excel, nombre_salida)

            # Guardar el DataFrame en un archivo Excel
            df_datos.to_excel(ruta_excel, index=False, engine='openpyxl')

            print(f"Archivo guardado: {ruta_excel}")

print("Proceso completado. Todos los archivos han sido convertidos a Excel.")
# Out:
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01003.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01006.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01008.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01009.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01010.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01011.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01012.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01013.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01015.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01017.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01020.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01023.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01026.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01028.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01029.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01031.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01032.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01033.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01045.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01046.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01078.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01081.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01084.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01088.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01091.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01095.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01103.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes05004.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes05175.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10032.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10047.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10057.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10067.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10070.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10074.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10081.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10088.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10099.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10135.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10172.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes11045.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14025.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14026.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14032.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14037.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14038.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14053.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14069.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14071.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14098.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14100.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14101.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14103.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14108.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14134.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14135.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14144.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14145.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14153.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14156.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14165.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14167.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14175.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14176.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14179.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14186.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14192.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14196.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14306.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14319.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14324.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14326.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14331.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14345.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14346.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes18031.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes19129.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24055.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24059.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24074.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24077.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24100.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24144.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24146.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24148.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24150.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24151.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24152.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24166.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24175.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24191.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24194.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24196.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32001.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32002.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32003.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32004.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32005.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32006.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32007.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32009.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32010.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32011.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32012.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32013.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32015.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32016.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32017.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32018.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32019.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32020.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32021.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32022.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32023.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32024.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32025.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32026.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32027.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32028.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32029.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32030.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32031.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32032.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32033.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32034.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32036.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32037.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32038.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32039.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32040.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32041.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32042.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32043.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32045.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32046.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32047.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32048.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32049.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32050.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32051.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32052.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32053.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32054.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32055.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32056.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32057.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32058.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32059.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32060.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32061.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32062.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32063.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32065.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32067.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32068.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32069.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32070.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32071.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32072.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32073.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32076.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32077.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32078.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32084.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32085.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32086.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32087.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32091.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32093.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32095.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32097.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32098.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32099.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32100.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32101.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32103.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32104.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32105.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32106.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32107.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32108.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32109.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32110.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32111.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32112.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32113.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32114.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32115.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32116.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32117.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32118.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32119.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32120.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32121.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32122.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32123.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32124.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32125.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32126.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32127.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32129.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32130.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32131.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32132.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32133.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32134.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32135.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32136.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32137.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32138.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32139.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32140.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32141.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32142.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32143.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32144.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32171.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32172.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32173.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32174.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32176.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32177.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32179.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32180.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32184.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32186.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32187.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32188.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32189.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Error al procesar C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32191.txt: Error tokenizing data. C error: Expected 6 fields in line 8, saw 11
#
# Proceso completado. Todos los archivos han sido convertidos a Excel.

# %%
import pandas as pd
import os
import re

# Definir carpetas
carpeta_txt = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES"
carpeta_excel = os.path.join(carpeta_txt, "MENSUALES_excel")

# Crear la carpeta de salida si no existe
if not os.path.exists(carpeta_excel):
    os.makedirs(carpeta_excel)

# Función para leer y procesar un archivo TXT
def procesar_archivo_txt(ruta_archivo):
    try:
        with open(ruta_archivo, "r", encoding="latin1") as file:
            lines = file.readlines()

        # Encontrar la línea donde comienzan los datos (evitar encabezados)
        inicio_datos = 0
        for i, line in enumerate(lines):
            if "FEB" in line and "ENE" in line:  # Detectar encabezado de la tabla
                inicio_datos = i
                
                break

        # Procesar las líneas asegurando alineación correcta
        datos_procesados = []
        for line in lines[inicio_datos:]:
            line = re.sub(r'\s+', ' ', line.strip())  # Reemplazar múltiples espacios con un solo espacio
            datos_procesados.append(line.split(' '))

        # Crear el DataFrame
        df = pd.DataFrame(datos_procesados)

        # Validar que la primera fila tiene los nombres correctos de las columnas
        if not set(["AÑO", "ENE", "FEB", "MAR", "ABR", "MAY", "JUN", "JUL", "AGO", "SEP", "OCT", "NOV", "DIC"]).issubset(set(df.iloc[0])):
            print(f"Advertencia: No se encontraron todas las columnas esperadas en {ruta_archivo}. Revisar formato.")
            return None

        # Asignar nombres de columnas basados en la primera fila
        df.columns = df.iloc[0]
        df = df[1:].reset_index(drop=True)

        # Convertir columnas numéricas al tipo adecuado
        columnas_numericas = ["AÑO", "ENE", "FEB", "MAR", "ABR", "MAY", "JUN", "JUL", "AGO", "SEP", "OCT", "NOV", "DIC"]
        df[columnas_numericas] = df[columnas_numericas].apply(pd.to_numeric, errors='coerce')

        return df
    except Exception as e:
        print(f"Error al procesar {ruta_archivo}: {e}")
        return None

# Procesar todos los archivos en la carpeta de TXT
for archivo in os.listdir(carpeta_txt):
    if archivo.endswith(".txt"):
        ruta_txt = os.path.join(carpeta_txt, archivo)

        # Procesar el archivo y obtener el DataFrame
        df_datos = procesar_archivo_txt(ruta_txt)

        if df_datos is not None:
            # Definir la ruta de salida en la carpeta MENSUALES_excel
            nombre_salida = os.path.splitext(archivo)[0] + ".xlsm"
            ruta_excel = os.path.join(carpeta_excel, nombre_salida)

            # Guardar el DataFrame en un archivo Excel
            df_datos.to_excel(ruta_excel, index=False, engine='openpyxl')

            print(f"Archivo guardado: {ruta_excel}")
        else:
            print(f"No se pudo procesar el archivo: {ruta_txt}")

print("Proceso completado. Todos los archivos han sido convertidos a Excel.")
# Out:
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01003.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01003.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01006.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01006.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01008.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01008.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01009.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01009.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01010.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01010.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01011.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01011.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01012.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01012.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01013.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01013.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01015.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01015.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01017.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01017.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01020.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01020.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01023.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01023.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01026.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01026.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01028.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01028.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01029.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01029.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01031.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01031.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01032.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01032.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01033.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01033.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01045.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01045.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01046.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01046.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01078.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01078.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01081.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01081.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01084.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01084.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01088.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01088.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01091.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01091.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01095.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01095.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01103.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01103.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes05004.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes05004.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes05175.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes05175.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10032.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10032.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10047.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10047.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10057.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10057.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10067.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10067.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10070.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10070.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10074.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10074.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10081.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10081.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10088.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10088.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10099.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10099.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10135.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10135.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10172.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10172.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes11045.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes11045.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14025.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14025.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14026.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14026.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14032.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14032.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14037.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14037.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14038.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14038.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14053.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14053.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14069.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14069.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14071.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14071.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14098.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14098.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14100.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14100.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14101.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14101.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14103.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14103.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14108.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14108.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14134.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14134.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14135.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14135.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14144.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14144.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14145.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14145.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14153.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14153.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14156.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14156.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14165.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14165.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14167.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14167.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14175.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14175.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14176.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14176.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14179.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14179.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14186.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14186.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14192.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14192.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14196.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14196.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14306.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14306.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14319.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14319.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14324.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14324.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14326.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14326.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14331.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14331.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14345.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14345.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14346.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14346.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes18031.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes18031.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes19129.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes19129.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24055.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24055.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24059.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24059.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24074.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24074.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24077.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24077.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24100.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24100.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24144.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24144.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24146.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24146.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24148.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24148.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24150.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24150.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24151.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24151.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24152.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24152.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24166.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24166.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24175.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24175.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24191.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24191.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24194.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24194.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24196.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24196.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32001.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32001.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32002.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32002.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32003.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32003.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32004.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32004.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32005.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32005.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32006.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32006.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32007.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32007.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32009.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32009.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32010.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32010.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32011.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32011.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32012.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32012.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32013.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32013.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32015.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32015.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32016.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32016.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32017.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32017.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32018.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32018.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32019.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32019.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32020.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32020.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32021.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32021.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32022.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32022.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32023.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32023.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32024.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32024.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32025.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32025.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32026.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32026.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32027.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32027.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32028.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32028.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32029.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32029.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32030.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32030.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32031.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32031.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32032.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32032.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32033.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32033.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32034.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32034.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32036.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32036.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32037.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32037.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32038.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32038.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32039.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32039.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32040.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32040.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32041.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32041.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32042.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32042.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32043.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32043.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32045.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32045.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32046.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32046.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32047.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32047.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32048.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32048.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32049.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32049.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32050.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32050.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32051.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32051.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32052.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32052.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32053.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32053.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32054.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32054.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32055.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32055.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32056.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32056.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32057.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32057.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32058.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32058.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32059.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32059.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32060.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32060.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32061.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32061.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32062.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32062.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32063.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32063.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32065.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32065.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32067.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32067.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32068.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32068.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32069.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32069.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32070.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32070.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32071.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32071.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32072.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32072.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32073.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32073.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32076.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32076.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32077.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32077.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32078.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32078.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32084.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32084.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32085.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32085.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32086.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32086.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32087.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32087.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32091.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32091.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32093.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32093.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32095.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32095.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32097.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32097.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32098.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32098.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32099.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32099.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32100.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32100.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32101.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32101.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32103.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32103.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32104.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32104.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32105.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32105.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32106.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32106.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32107.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32107.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32108.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32108.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32109.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32109.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32110.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32110.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32111.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32111.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32112.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32112.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32113.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32113.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32114.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32114.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32115.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32115.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32116.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32116.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32117.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32117.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32118.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32118.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32119.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32119.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32120.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32120.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32121.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32121.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32122.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32122.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32123.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32123.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32124.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32124.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32125.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32125.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32126.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32126.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32127.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32127.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32129.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32129.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32130.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32130.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32131.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32131.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32132.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32132.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32133.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32133.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32134.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32134.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32135.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32135.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32136.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32136.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32137.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32137.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32138.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32138.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32139.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32139.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32140.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32140.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32141.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32141.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32142.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32142.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32143.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32143.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32144.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32144.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32171.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32171.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32172.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32172.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32173.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32173.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32174.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32174.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32176.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32176.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32177.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32177.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32179.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32179.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32180.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32180.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32184.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32184.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32186.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32186.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32187.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32187.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32188.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32188.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32189.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32189.txt
# Advertencia: No se encontraron todas las columnas esperadas en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32191.txt. Revisar formato.
# No se pudo procesar el archivo: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32191.txt
# Proceso completado. Todos los archivos han sido convertidos a Excel.

# %%
import os
import pandas as pd

# Ruta de la carpeta donde están los archivos TXT
carpeta_txt = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES"
carpeta_excel = os.path.join(carpeta_txt, "MENSUALES_excel")

# Crear carpeta de salida si no existe
if not os.path.exists(carpeta_excel):
    os.makedirs(carpeta_excel)

# Función para procesar un archivo TXT
def procesar_archivo_txt(ruta_txt):
    with open(ruta_txt, "r", encoding="latin-1") as archivo:
        lineas = archivo.readlines()
    
    tablas = []
    tabla_actual = []
    nombre_tabla = None

    for linea in lineas:
        # Buscar encabezados de tabla (AÑO, ENE, FEB...)
        if "AÑO" in linea:
            if tabla_actual:  # Si hay una tabla en curso, guardarla
                tablas.append((nombre_tabla, tabla_actual))
                tabla_actual = []

            nombre_tabla = lineas[lineas.index(linea) - 1].strip()  # Nombre de la tabla anterior
            tabla_actual.append(linea.strip())

        elif tabla_actual:
            # Seguir agregando líneas hasta encontrar otra tabla o el final del archivo
            if linea.strip():
                tabla_actual.append(linea.strip())
    
    # Guardar última tabla si existe
    if tabla_actual:
        tablas.append((nombre_tabla, tabla_actual))

    if not tablas:
        print(f"No se encontró ninguna tabla en {ruta_txt}")
        return
    
    # Crear archivo Excel con todas las tablas en hojas separadas
    nombre_excel = os.path.join(carpeta_excel, os.path.basename(ruta_txt).replace(".txt", ".xlsx"))
    with pd.ExcelWriter(nombre_excel) as writer:
        for nombre_tabla, datos_tabla in tablas:
            try:
                df = pd.DataFrame([fila.split() for fila in datos_tabla[1:]], columns=datos_tabla[0].split())
                df.to_excel(writer, sheet_name=nombre_tabla[:31], index=False)  # Hoja máx 31 caracteres
            except Exception as e:
                print(f"Error al procesar tabla '{nombre_tabla}' en {ruta_txt}: {e}")

    print(f"Archivo procesado: {nombre_excel}")

# Procesar todos los archivos TXT en la carpeta
archivos_txt = [f for f in os.listdir(carpeta_txt) if f.endswith(".txt")]

for archivo in archivos_txt:
    procesar_archivo_txt(os.path.join(carpeta_txt, archivo))

print("✅ Proceso completado. Todos los archivos han sido convertidos a Excel.")
# Out:
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01003.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01006.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01008.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01009.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01010.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01011.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01012.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01013.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01015.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01017.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01020.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01023.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01026.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01028.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01029.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01031.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01032.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01033.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01045.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01046.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01078.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01081.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01084.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01088.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01091.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01095.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes01103.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes05004.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes05175.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10032.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10047.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10057.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10067.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10070.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10074.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10081.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10088.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10099.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10135.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes10172.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes11045.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14025.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14026.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14032.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14037.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14038.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14053.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14069.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14071.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14098.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14100.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14101.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14103.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14108.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14134.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14135.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14144.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14145.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14153.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14156.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14165.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14167.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14175.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14176.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14179.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14186.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14192.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14196.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14306.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14319.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14324.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14326.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14331.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14345.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes14346.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes18031.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes19129.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24055.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24059.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24074.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24077.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24100.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24144.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24146.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24148.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24150.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24151.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24152.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24166.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24175.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24191.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24194.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes24196.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32001.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32002.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32003.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32004.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32005.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32006.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32007.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32009.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32010.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32011.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32012.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32013.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32015.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32016.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32017.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32018.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32019.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32020.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32021.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32022.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32023.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32024.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32025.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32026.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32027.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32028.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32029.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32030.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32031.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32032.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32033.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32034.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32036.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32037.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32038.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32039.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32040.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32041.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32042.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32043.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32045.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32046.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32047.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32048.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32049.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32050.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32051.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32052.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32053.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32054.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32055.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32056.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32057.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32058.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32059.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32060.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32061.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32062.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32063.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32065.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32067.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32068.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32069.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32070.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32071.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32072.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32073.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32076.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32077.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32078.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32084.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32085.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32086.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32087.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32091.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32093.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32095.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32097.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32098.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32099.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32100.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32101.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32103.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32104.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32105.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32106.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32107.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32108.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32109.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32110.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32111.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32112.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32113.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32114.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32115.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32116.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32117.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32118.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32119.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32120.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32121.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32122.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32123.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32124.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32125.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32126.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32127.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32129.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32130.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32131.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32132.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32133.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32134.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32135.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32136.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32137.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32138.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32139.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32140.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32141.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32142.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32143.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32144.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32171.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32172.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32173.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32174.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32176.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32177.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32179.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32180.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32184.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32186.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32187.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32188.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32189.txt
# No se encontró ninguna tabla en C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES\mes32191.txt
# ✅ Proceso completado. Todos los archivos han sido convertidos a Excel.

# %%
# import pandas as pd

# # Ruta del archivo de texto
# file_path = "/mnt/data/mes01003.txt"

# # Leer el archivo de texto línea por línea con la codificación adecuada
# with open(file_path, "r", encoding="latin-1") as file:
#     lines = file.readlines()

# # Diccionario de nombres corregidos de las tablas en el archivo
# table_names_extended = {
#     "LLUVIA MÁXIMA 24 H.": "LLUVIA MÃ\x81XIMA 24 H.",
#     "LLUVIA TOTAL MENSUAL": "LLUVIA TOTAL MENSUAL",
#     "EVAPORACIÓN MENSUAL": "EVAPORACIÃ\x93N MENSUAL",
#     "TEMPERATURA MÁXIMA PROMEDIO": "TEMPERATURA MÃ\x81XIMA PROMEDIO",
#     "TEMPERATURA MÁXIMA EXTREMA": "TEMPERATURA MÃ\x81XIMA EXTREMA",
#     "TEMPERATURA MÍNIMA PROMEDIO": "TEMPERATURA MÃ\x8dNIMA PROMEDIO",
#     "TEMPERATURA MÍNIMA EXTREMA": "TEMPERATURA MÃ\x8dNIMA EXTREMA",
#     "TEMPERATURA MEDIA MENSUAL": "TEMPERATURA MEDIA MENSUAL",
# }

# # Almacenar las tablas encontradas
# tables = {}
# current_table = None
# current_data = []

# # Procesar línea por línea
# for line in lines:
#     line = line.strip()
#     if line in table_names_extended.values():  # Nueva tabla encontrada
#         if current_table and current_data:
#             tables[current_table] = pd.DataFrame(current_data)
#         # Obtener el nombre real de la tabla
#         current_table = [key for key, value in table_names_extended.items() if value == line][0]
#         current_data = []
#     elif current_table:
#         # Agregar datos a la tabla actual
#         columns = line.split("\t")
#         current_data.append(columns)

# # Guardar última tabla
# if current_table and current_data:
#     tables[current_table] = pd.DataFrame(current_data)

# # Crear un archivo Excel con todas las tablas en hojas separadas
# excel_path = "/mnt/data/datos_climatologicos_completo.xlsx"
# with pd.ExcelWriter(excel_path) as writer:
#     for table_name, df in tables.items():
#         # Asignar la primera fila como encabezados
#         df.columns = df.iloc[0]
#         df = df[1:].reset_index(drop=True)
#         df.to_excel(writer, sheet_name=table_name[:31], index=False)

# # Mostrar el archivo generado
# excel_path

# %%
# import pandas as pd
# import re

# # Ruta del archivo de texto
# file_path = "/mnt/data/mes01003.txt"

# # Leer el archivo de texto con codificación adecuada
# with open(file_path, "r", encoding="latin-1") as file:
#     lines = file.readlines()

# # Diccionario de nombres corregidos de las tablas en el archivo
# table_names_extended = {
#     "LLUVIA MÁXIMA 24 H.": "LLUVIA MÃ\x81XIMA 24 H.",
#     "LLUVIA TOTAL MENSUAL": "LLUVIA TOTAL MENSUAL",
#     "EVAPORACIÓN MENSUAL": "EVAPORACIÃ\x93N MENSUAL",
#     "TEMPERATURA MÁXIMA PROMEDIO": "TEMPERATURA MÃ\x81XIMA PROMEDIO",
#     "TEMPERATURA MÁXIMA EXTREMA": "TEMPERATURA MÃ\x81XIMA EXTREMA",
#     "TEMPERATURA MÍNIMA PROMEDIO": "TEMPERATURA MÃ\x8dNIMA PROMEDIO",
#     "TEMPERATURA MÍNIMA EXTREMA": "TEMPERATURA MÃ\x8dNIMA EXTREMA",
#     "TEMPERATURA MEDIA MENSUAL": "TEMPERATURA MEDIA MENSUAL",
# }

# # Almacenar las tablas encontradas
# tables = {}
# current_table = None
# current_data = []

# # Procesar línea por línea
# for line in lines:
#     line = line.strip()
#     if line in table_names_extended.values():  # Nueva tabla encontrada
#         if current_table and current_data:
#             tables[current_table] = pd.DataFrame(current_data)
#         # Obtener el nombre real de la tabla
#         current_table = [key for key, value in table_names_extended.items() if value == line][0]
#         current_data = []
#     elif current_table:
#         # Agregar datos a la tabla actual
#         columns = line.split("\t")
#         current_data.append(columns)

# # Guardar última tabla
# if current_table and current_data:
#     tables[current_table] = pd.DataFrame(current_data)

# # Función para limpiar nombres de columnas y valores de filas
# def clean_column_names(name):
#     replacements = {
#         "AÃ\x91O": "ANIO",
#         "MÃ\x8dNIMA": "MINIMA",
#         "MÃ\x81XIMA": "MAXIMA",
#     }
#     for old, new in replacements.items():
#         name = name.replace(old, new)
#     return name

# # Crear un archivo Excel con todas las tablas en hojas separadas
# excel_path = "/mnt/data/datos_climatologicos_final.xlsx"
# with pd.ExcelWriter(excel_path) as writer:
#     for table_name, df in tables.items():
#         # Limpiar encabezados
#         df.columns = df.iloc[0].apply(clean_column_names)
#         df = df[1:].reset_index(drop=True)

#         # Limpiar valores dentro de la tabla
#         df = df.applymap(lambda x: clean_column_names(str(x)))

#         # Guardar en Excel
#         df.to_excel(writer, sheet_name=table_name[:31], index=False)

# # Mostrar el archivo generado
# excel_path

# %%
import os
import pandas as pd
import xlwings as xw

# Carpetas de entrada y salida
carpeta_txt = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES"
carpeta_excel = os.path.join(carpeta_txt, "MENSUALES_excel")

# Crear la carpeta de salida si no existe
os.makedirs(carpeta_excel, exist_ok=True)

# Diccionario de nombres corregidos de las tablas (NO modificar)
table_names_extended = {
    "LLUVIA MÁXIMA 24 H.": "LLUVIA MÃ\x81XIMA 24 H.",
    "LLUVIA TOTAL MENSUAL": "LLUVIA TOTAL MENSUAL",
    "EVAPORACIÓN MENSUAL": "EVAPORACIÃ\x93N MENSUAL",
    "TEMPERATURA MÁXIMA PROMEDIO": "TEMPERATURA MÃ\x81XIMA PROMEDIO",
    "TEMPERATURA MÁXIMA EXTREMA": "TEMPERATURA MÃ\x81XIMA EXTREMA",
    "TEMPERATURA MÍNIMA PROMEDIO": "TEMPERATURA MÃ\x8dNIMA PROMEDIO",
    "TEMPERATURA MÍNIMA EXTREMA": "TEMPERATURA MÃ\x8dNIMA EXTREMA",
    "TEMPERATURA MEDIA MENSUAL": "TEMPERATURA MEDIA MENSUAL",
}

# Función para limpiar nombres de columnas y valores de filas
def clean_column_names(name):
    replacements = {
        "AÃ\x91O": "ANIO",
        "MÃ\x8dNIMA": "MINIMA",
        "MÃ\x81XIMA": "MAXIMA",
    }
    for old, new in replacements.items():
        name = name.replace(old, new)
    return name

# Función para procesar un archivo TXT y convertirlo a XLSM
def procesar_txt_a_xlsm(file_path, output_path):
    with open(file_path, "r", encoding="latin-1") as file:
        lines = file.readlines()

    tables = {}
    current_table = None
    current_data = []

    for line in lines:
        line = line.strip()
        if line in table_names_extended.values():
            if current_table and current_data:
                tables[current_table] = pd.DataFrame(current_data)
            current_table = [key for key, value in table_names_extended.items() if value == line][0]
            current_data = []
        elif current_table:
            columns = line.split("\t")
            current_data.append(columns)

    if current_table and current_data:
        tables[current_table] = pd.DataFrame(current_data)

    # Eliminar la última fila de cada tabla si contiene valores None o está vacía
    for table_name in list(tables.keys()):  # Convertimos a lista para evitar errores al modificar el diccionario
        if not tables[table_name].empty:
            while tables[table_name].iloc[-1].isnull().all() or tables[table_name].iloc[-1].eq('').all():
                tables[table_name] = tables[table_name].iloc[:-1]

    # Crear archivo XLSM con xlwings
    app = xw.App(visible=False)
    wb = app.books.add()

    for table_name, df in tables.items():
        if not df.empty:
            sheet_name = table_name[:31]  # Máximo 31 caracteres en nombres de hojas
            sht = wb.sheets.add(sheet_name)
            
            # Verificar si el DataFrame tiene encabezados
            if len(df) > 1:
                # Limpiar encabezados correctamente
                df.columns = df.iloc[0].apply(clean_column_names)  # Aplica limpieza a los encabezados
                df = df[1:].reset_index(drop=True)  # Elimina la fila duplicada de encabezado
            else:
                df.columns = [clean_column_names(col) for col in df.columns]  # Limpia si hay solo una fila
            
            # Limpiar valores dentro de la tabla
            df = df.applymap(lambda x: clean_column_names(str(x)))

            # Escribir los encabezados en Excel
            sht.range("A1").value = df.columns.tolist()

            # Escribir los datos en Excel debajo de los encabezados
            if not df.empty:
                sht.range("A2").value = df.values

    # Guardar como XLSM
    wb.sheets[0].delete()  # Eliminar hoja en blanco creada por defecto
    wb.save(output_path)
    wb.close()
    app.quit()

# Procesar todos los archivos TXT en la carpeta
for archivo in os.listdir(carpeta_txt):
    if archivo.endswith(".txt"):
        ruta_txt = os.path.join(carpeta_txt, archivo)
        nombre_salida = os.path.splitext(archivo)[0] + ".xlsm"
        ruta_xlsm = os.path.join(carpeta_excel, nombre_salida)
        
        print(f"Procesando {archivo} → {nombre_salida}...")
        procesar_txt_a_xlsm(ruta_txt, ruta_xlsm)

print("✅ Conversión completa. Archivos guardados en:", carpeta_excel)
# Out:
# Procesando mes01003.txt → mes01003.xlsm...
# Procesando mes01006.txt → mes01006.xlsm...
# Procesando mes01008.txt → mes01008.xlsm...
# Procesando mes01009.txt → mes01009.xlsm...
# Procesando mes01010.txt → mes01010.xlsm...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [48], in <cell line: 98>()
#     102         ruta_xlsm = os.path.join(carpeta_excel, nombre_salida)
#     104         print(f"Procesando {archivo} → {nombre_salida}...")
# --> 105         procesar_txt_a_xlsm(ruta_txt, ruta_xlsm)
#     107 print("✅ Conversión completa. Archivos guardados en:", carpeta_excel)
#
# Input In [48], in procesar_txt_a_xlsm(file_path, output_path)
#      87         # Escribir los datos en Excel debajo de los encabezados
#      88         if not df.empty:
# ---> 89             sht.range("A2").value = df.values
#      91 # Guardar como XLSM
#      92 wb.sheets[0].delete()  # Eliminar hoja en blanco creada por defecto
#
# File ~\anaconda3\lib\site-packages\xlwings\main.py:1997, in Range.value(self, data)
#    1995 @value.setter
#    1996 def value(self, data):
# -> 1997     conversion.write(data, self, self._options)
#
# File ~\anaconda3\lib\site-packages\xlwings\conversion\__init__.py:48, in write(value, rng, options)
#      46 pipeline = accessors.get(convert, convert).router(value, rng, options).writer(options)
#      47 ctx = ConversionContext(rng=rng, value=value)
# ---> 48 pipeline(ctx)
#      49 return ctx.value
#
# File ~\anaconda3\lib\site-packages\xlwings\conversion\framework.py:66, in Pipeline.__call__(self, *args, **kwargs)
#      64 def __call__(self, *args, **kwargs):
#      65     for stage in self:
# ---> 66         stage(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\xlwings\conversion\standard.py:74, in WriteValueToRangeStage.__call__(self, ctx)
#      71 if not scalar:
#      72     ctx.range = ctx.range.resize(len(ctx.value), len(ctx.value[0]))
# ---> 74 self._write_value(ctx.range, ctx.value, scalar)
#
# File ~\anaconda3\lib\site-packages\xlwings\conversion\standard.py:62, in WriteValueToRangeStage._write_value(self, rng, value, scalar)
#      60         rng[ix * chunksize:ix * chunksize + chunksize, :].raw_value = value_chunk
#      61 else:
# ---> 62     rng.raw_value = value
#
# File ~\anaconda3\lib\site-packages\xlwings\main.py:1590, in Range.raw_value(self, data)
#    1588 @raw_value.setter
#    1589 def raw_value(self, data):
# -> 1590     self.impl.raw_value = data
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:842, in Range.raw_value(self, data)
#     839 @raw_value.setter
#     840 def raw_value(self, data):
#     841     if self.xl is not None:
# --> 842         self.xl.Value = data
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:107, in COMRetryObjectWrapper.__setattr__(self, key, value)
#     105 while True:
#     106     try:
# --> 107         return setattr(self._inner, key, value)
#     108     except pywintypes.com_error as e:
#     109         # -2147352567 is the error you get when clicking into cells
#     110         if (not N_COM_ATTEMPTS or n_attempt < N_COM_ATTEMPTS) and e.hresult in [-2147418111, -2147352567]:
#
# File ~\anaconda3\lib\site-packages\win32com\client\__init__.py:595, in DispatchBaseClass.__setattr__(self, attr, value)
#     591 except KeyError:
#     592     raise AttributeError(
#     593         "'%s' object has no attribute '%s'" % (repr(self), attr)
#     594     )
# --> 595 self._oleobj_.Invoke(*(args + (value,) + defArgs))
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
import xlwings as xw

# Directorios
input_folder = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES"
output_folder = r"C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel"

# Crear la carpeta de salida si no existe
os.makedirs(output_folder, exist_ok=True)

# Diccionario de nombres corregidos de las tablas en el archivo
table_names_extended = {
    "LLUVIA MÁXIMA 24 H.": "LLUVIA MÃ\x81XIMA 24 H.",
    "LLUVIA TOTAL MENSUAL": "LLUVIA TOTAL MENSUAL",
    "EVAPORACIÓN MENSUAL": "EVAPORACIÃ\x93N MENSUAL",
    "TEMPERATURA MÁXIMA PROMEDIO": "TEMPERATURA MÃ\x81XIMA PROMEDIO",
    "TEMPERATURA MÁXIMA EXTREMA": "TEMPERATURA MÃ\x81XIMA EXTREMA",
    "TEMPERATURA MÍNIMA PROMEDIO": "TEMPERATURA MÃ\x8dNIMA PROMEDIO",
    "TEMPERATURA MÍNIMA EXTREMA": "TEMPERATURA MÃ\x8dNIMA EXTREMA",
    "TEMPERATURA MEDIA MENSUAL": "TEMPERATURA MEDIA MENSUAL",
}

# Función para limpiar nombres de columnas y valores de filas
def clean_column_names(name):
    replacements = {
        "AÃ\x91O": "ANIO",
        "MÃ\x8dNIMA": "MINIMA",
        "MÃ\x81XIMA": "MAXIMA",
    }
    for old, new in replacements.items():
        name = name.replace(old, new)
    return name

# Procesar todos los archivos .txt en la carpeta de entrada
for filename in os.listdir(input_folder):
    if filename.endswith(".txt"):
        file_path = os.path.join(input_folder, filename)
        with open(file_path, "r", encoding="latin-1") as file:
            lines = file.readlines()

        # Almacenar las tablas encontradas
        tables = {}
        current_table = None
        current_data = []

        for line in lines:
            line = line.strip()
            if line in table_names_extended.values():  # Nueva tabla encontrada
                if current_table and current_data:
                    tables[current_table] = pd.DataFrame(current_data)
                current_table = [key for key, value in table_names_extended.items() if value == line][0]
                current_data = []
            elif current_table:
                columns = line.split("\t")
                current_data.append(columns)

        # Guardar última tabla
        if current_table and current_data:
            tables[current_table] = pd.DataFrame(current_data)

        # Eliminar la última fila de cada tabla si está vacía
        for table_name in tables:
            if tables[table_name].iloc[-1].isnull().all() or tables[table_name].iloc[-1].eq('').all():
                tables[table_name] = tables[table_name].iloc[:-1]

        # Crear un archivo Excel con todas las tablas en hojas separadas
        output_file = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.xlsm")
        
        app = xw.App(visible=False)  # Inicia Excel en segundo plano
        wb = app.books.add()  # Crea un nuevo libro de Excel

        for table_name, df in tables.items():
            df.columns = df.iloc[0].apply(clean_column_names)
            df = df[1:].reset_index(drop=True)
            df = df.applymap(lambda x: clean_column_names(str(x)))

            # Agregar hoja y escribir datos
            sheet = wb.sheets.add(name=table_name[:31])
            sheet.range("A1").value = df

        wb.save(output_file)
        wb.close()
        app.quit()

print("Conversión completada. Archivos guardados en:", output_folder)
# Out:
# Conversión completada. Archivos guardados en: C:\Users\ALEN\Documents\trabajo doc bautista\climatologia\MENSUALES_excel
